# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from datetime import datetime
from kneed import KneeLocator
import seaborn as sns
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# Let's load the data and show the data types to verify that we are working with numerical data

# %%
# Load the dataset
df = pd.read_csv('../timeseries_datasets/tracks.csv')

# %%
artist_name_map = {
    "ART25707984": "fabri fibra",
    "ART07024718": "fedez"
}

# %% [markdown]
# We can see that no null value is present in this dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        440 non-null    object
#  1   id_artist                 440 non-null    object
#  2   num_samples               440 non-null    int64
#  3   sr                        440 non-null    int64
#  4   duration_ms               440 non-null    float64
#  5   bpm                       440 non-null    float64
#  6   centroid_mean             440 non-null    float64
#  7   centroid_std              440 non-null    float64
#  8   rolloff_mean              440 non-null    float64
#  9   rolloff_std               440 non-null    float64
#  10  flux_mean                 440 non-null    float64
#  11  flux_std                  440 non-null    float64
#  12  rms_mean                  440 non-null    float64
# ...

# %%
df.dtypes
# Out:
# id                           object
# id_artist                    object
# num_samples                   int64
# sr                            int64
# duration_ms                 float64
# bpm                         float64
# centroid_mean               float64
# centroid_std                float64
# rolloff_mean                float64
# rolloff_std                 float64
# flux_mean                   float64
# flux_std                    float64
# rms_mean                    float64
# rms_std                     float64
# zcr_mean                    float64
# zcr_std                     float64
# flatness_mean               float64
# flatness_std                float64
# spectral_complexity_mean    float64
# spectral_complexity_std     float64
# pitch_mean                  float64
# pitch_std                   float64
# loudness_mean               float64
# loudness_std                float64
# silence_start_sec           float64
# silence_end_sec             float64
# ...

# %%
df.head()
# Out:
#          id    id_artist  num_samples     sr  duration_ms         bpm  \
# 0  TR597348  ART25707984      1323000  22050      60000.0  103.359375
# 1  TR745549  ART07024718      1323000  22050      60000.0  184.570312
# 2  TR324941  ART25707984      1323000  22050      60000.0  161.499023
# 3  TR496653  ART07024718      1323000  22050      60000.0   92.285156
# 4  TR910855  ART25707984      1323000  22050      60000.0   95.703125
#
#    centroid_mean  centroid_std  rolloff_mean  rolloff_std  ...  pitch_mean  \
# 0    1829.634696    513.633085   3632.365536  1251.702789  ...  166.056295
# 1    3104.869592    865.268063   6785.379803  1396.211133  ...   94.284803
# 2    2681.050056    830.110964   5994.026255  1533.435198  ...  123.373624
# 3    2433.401636    914.693105   5803.939904  1797.581388  ...   91.459176
# 4    2960.550410    864.289578   6550.868721  1524.216276  ...  135.255304
#
#    pitch_std  loudness_mean  loudness_std  silence_start_sec  silence_end_sec  \
# ...

# %% [markdown]
# ## Data exploration
# In this step we explore the dataset prepared for clustering and check for data distribution

# %%
df.drop(["id", "num_samples", "duration_ms", "sr", "centroid_std", "rolloff_std", "flux_std", "rms_std", "zcr_std", "flatness_std", "spectral_complexity_std", "pitch_std", "loudness_std", "silence_middle_total_sec", "is_silent"], axis=1, inplace=True)

# %%
df.head()
# Out:
#      id_artist         bpm  centroid_mean  rolloff_mean  flux_mean  rms_mean  \
# 0  ART25707984  103.359375    1829.634696   3632.365536   1.913256  0.256541
# 1  ART07024718  184.570312    3104.869592   6785.379803   1.476795  0.240214
# 2  ART25707984  161.499023    2681.050056   5994.026255   1.723460  0.141660
# 3  ART07024718   92.285156    2433.401636   5803.939904   1.509449  0.292506
# 4  ART25707984   95.703125    2960.550410   6550.868721   1.808202  0.271711
#
#    zcr_mean  flatness_mean  spectral_complexity_mean  pitch_mean  \
# 0  0.075866       0.006975               2133.886542  166.056295
# 1  0.142538       0.059145               2936.665151   94.284803
# 2  0.112018       0.033351               2762.948751  123.373624
# 3  0.076226       0.017405               2856.940934   91.459176
# 4  0.117349       0.036084               2912.308380  135.255304
#
#    loudness_mean  silence_start_sec  silence_end_sec  silence_middle_count  \
# ...

# %% [markdown]
# Now we plot the data distribution and check for each column what are the values

# %%
musical_cols = df.columns

fig, axs = plt.subplots(len(musical_cols), 1, figsize=(8, 3*len(musical_cols)))
for i,c in enumerate(musical_cols):
    ax = axs[i] if len(musical_cols)>1 else axs
    sns.histplot(df[c].dropna(), kde=True, ax=ax)
    ax.set_title(f'Distribution of {c}')
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Normalizing data
# In this step we normalize the dataset using the standard scaler so that all values are brought in the same range values.
# We also exclude the artist id column as it is not used in clustering

# %%
clustering_df = df.iloc[:,1:]
clustering_df.head()
# Out:
#           bpm  centroid_mean  rolloff_mean  flux_mean  rms_mean  zcr_mean  \
# 0  103.359375    1829.634696   3632.365536   1.913256  0.256541  0.075866
# 1  184.570312    3104.869592   6785.379803   1.476795  0.240214  0.142538
# 2  161.499023    2681.050056   5994.026255   1.723460  0.141660  0.112018
# 3   92.285156    2433.401636   5803.939904   1.509449  0.292506  0.076226
# 4   95.703125    2960.550410   6550.868721   1.808202  0.271711  0.117349
#
#    flatness_mean  spectral_complexity_mean  pitch_mean  loudness_mean  \
# 0       0.006975               2133.886542  166.056295      -6.099958
# 1       0.059145               2936.665151   94.284803      -4.782125
# 2       0.033351               2762.948751  123.373624      -6.170307
# 3       0.017405               2856.940934   91.459176      -7.353655
# 4       0.036084               2912.308380  135.255304      -5.228243
#
#    silence_start_sec  silence_end_sec  silence_middle_count  \
# ...

# %%
scaler = StandardScaler()
# apply scaling
X_scaled = scaler.fit_transform(clustering_df.values)
X_scaled
# Out:
# array([[-0.64637621, -2.21652713, -2.70437046, ..., -0.05501943,
#         -0.15209075, -0.33487165],
#        [ 2.18535288,  1.3146874 ,  1.25085947, ..., -0.05501943,
#         -0.5457374 , -0.50862581],
#        [ 1.38088439,  0.14110149,  0.25816329, ..., -0.05501943,
#         -0.34891408,  0.18639083],
#        ...,
#        [ 0.2546285 ,  1.16157791,  1.07933836, ..., -0.05501943,
#         -0.15209075,  0.82348941],
#        [ 0.491735  ,  0.20159722,  0.61536478, ..., -0.05501943,
#         -0.5457374 , -0.50862581],
#        [-0.1549191 , -0.42206979, -0.57324055, ..., -0.05501943,
#         -0.41452185,  8.93201685]], shape=(440, 14))

# %% [markdown]
# ## K-means execution
# Now we run k means testing k values from 2 to 10, we store SSE and silhouette scores for each k tested

# %%
k_range = range(2, 10)
sse_values = []
silhouette_scores = []

for k in k_range:
    print(f"Fitting k: {k}", end=" ")

    # run k means
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    cluster_labels = kmeans.fit_predict(X_scaled)

    # get SSE
    sse = kmeans.inertia_
    sse_values.append(sse)

    # compute silhouette score
    silhouette_avg = silhouette_score(X_scaled, cluster_labels)
    silhouette_scores.append(silhouette_avg)

    print(f"SSE: {sse:.2f} - Silhouette Score: {silhouette_avg:.4f}")
# Out:
# Fitting k: 2 SSE: 5009.46 - Silhouette Score: 0.2361
# Fitting k: 3 SSE: 4357.56 - Silhouette Score: 0.1973
# Fitting k: 4
# SSE: 3917.94 - Silhouette Score: 0.2045
# Fitting k: 5 SSE: 3556.19 - Silhouette Score: 0.1468
# Fitting k: 6 SSE: 3134.20 - Silhouette Score: 0.1530
# Fitting k: 7 SSE: 2892.38 - Silhouette Score: 0.1662
# Fitting k: 8 SSE: 2643.74 - Silhouette Score: 0.1757
# Fitting k: 9 SSE: 2478.56 - Silhouette Score: 0.1448

# %%
kneedle = KneeLocator(k_range, sse_values, curve='convex', direction='decreasing')
best_k = kneedle.elbow

print(f"Best K = {best_k}. Elbow method on SSE")
# Out:
# Best K = 6. Elbow method on SSE

# %% [markdown]
# ## Visualization
# Finally we can plot how silhouette scores are distributed for each k value and

# %%
plt.figure(figsize=(10, 6))
plt.plot(k_range, sse_values, 'bo-', linewidth=2, markersize=8)
plt.xlabel('Number of Clusters', fontsize=12)
plt.ylabel('SSE', fontsize=12)
plt.title('SSE vs Number of Clusters', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.xticks(k_range)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(k_range, silhouette_scores, 'ro-', linewidth=2, markersize=8)
plt.axvline(x=best_k, color='g', linestyle='--', linewidth=2, label=f'Best k: {best_k}')
plt.xlabel('Number of Clusters', fontsize=12)
plt.ylabel('Silhouette Score', fontsize=12)
plt.title('Silhouette Score vs Number of Clusters', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.legend()
plt.xticks(k_range)
plt.tight_layout()
plt.show()

# %%
def k_means_run_analysis(num_clusters, num_pca_components):
    print(f"=========== Testing K-means with K = {num_clusters} ===========")
    kmeans_best = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
    best_k_labels = kmeans_best.fit_predict(X_scaled)
    
    # plot pca componetns
    pca = PCA(n_components=num_pca_components)
    X_pca = pca.fit_transform(X_scaled)
    
    plt.figure(figsize=(10, 6))
    scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=best_k_labels,
                                cmap='viridis', edgecolors='k')
    plt.xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.2%} variance)', fontsize=12)
    plt.ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.2%} variance)', fontsize=12)
    plt.title(f'K-means with k: {num_clusters}',
                        fontsize=14, fontweight='bold')
    
    # plot cluster sizes
    # cluster sizes
    plt.figure(figsize=(10, 6))
    cluster_counts = pd.Series(best_k_labels).value_counts().sort_index()
    plt.bar(cluster_counts.index, cluster_counts.values, color='steelblue', edgecolor='black')
    plt.xlabel('Cluster Number', fontsize=12)
    plt.ylabel('Cluster Elements', fontsize=12)
    plt.title(f'Cluster Sizes k: {num_clusters}', fontsize=14, fontweight='bold')
    plt.grid(True, alpha=0.3, axis='y')
    
    # box plot of features
    n_features = len(clustering_df.columns)
    n_cols = 4
    n_rows = (n_features + n_cols - 1) // n_cols

    fig3, axes3 = plt.subplots(n_rows, n_cols, figsize=(20, n_rows * 4))
    axes3 = axes3.flatten()
    
    clustering_df['cluster'] = best_k_labels
    # skip cluster column which is generated by k means
    feature_columns = [col for col in clustering_df.columns if col != 'cluster']

    for idx, column in enumerate(feature_columns):
        ax = axes3[idx]

        # Prepare data for boxplot
        data_by_cluster = [clustering_df[clustering_df['cluster'] == i][column].values
                        for i in range(num_clusters)]

        bp = ax.boxplot(data_by_cluster, labels=[f'C{i}' for i in range(num_clusters)],
                        patch_artist=True, showmeans=True)

        # Color the boxplots
        colors = plt.cm.viridis(np.linspace(0, 1, num_clusters))
        for patch, color in zip(bp['boxes'], colors):
            patch.set_facecolor(color)
            patch.set_alpha(0.7)

        ax.set_title(column, fontsize=11, fontweight='bold')
        ax.grid(True, alpha=0.3, axis='y')
        
    plt.show()

# %% [markdown]
# We can see that the optimal value found with the elbow method is k = 3 clusters.
# From Silhouette score we can see that the optimal value would be k = 2 with k = 5 and k = 7 following.
# Let's analyze all values and see the results

# %%
k_to_test = [2,3,4,6]

for k in k_to_test:
    k_means_run_analysis(num_clusters=k, num_pca_components=2)
# Out:
# =========== Testing K-means with K = 2 ===========
# =========== Testing K-means with K = 3 ===========
# =========== Testing K-means with K = 4 ===========
# =========== Testing K-means with K = 6 ===========

# %% [markdown]
# # Cluster analysis

# %%
from sklearn.manifold import TSNE

def plot_tsne(num_clusters, perplexity=35, n_iter=1000):
    
    # cluster using k means
    kmeans = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
    cluster_labels = kmeans.fit_predict(X_scaled)
    
    # compute t sne
    tsne = TSNE(n_components=2, perplexity=perplexity, max_iter=n_iter, random_state=42)
    X_tsne = tsne.fit_transform(X_scaled)
    
    plt.figure(figsize=(12, 8))
    scatter = plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=cluster_labels,
                         cmap='viridis', edgecolors='k', alpha=0.6, s=50)
    plt.colorbar(scatter, label='Cluster')
    plt.xlabel('t-SNE Comp 1')
    plt.ylabel('t-SNE Comp 2')
    plt.title(f't-SNE k: {num_clusters}', 
              fontsize=14, fontweight='bold')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# compute t sne for all k values
for k in k_to_test:
    plot_tsne(num_clusters=k)

# %% [markdown]
# We extract below the numerical features, excluding the cluster label column so that we can plot the radar plot for each cluster found

# %%
clustering_df.columns
# Out:
# Index(['bpm', 'centroid_mean', 'rolloff_mean', 'flux_mean', 'rms_mean',
#        'zcr_mean', 'flatness_mean', 'spectral_complexity_mean', 'pitch_mean',
#        'loudness_mean', 'silence_start_sec', 'silence_end_sec',
#        'silence_middle_count', 'silence_middle_mean_sec', 'cluster'],
#       dtype='object')

# %%
from math import pi

numeric_features = ['bpm', 'centroid_mean', 'rolloff_mean', 'flux_mean', 'rms_mean',
       'zcr_mean', 'flatness_mean', 'spectral_complexity_mean', 'pitch_mean',
       'loudness_mean', 'silence_start_sec', 'silence_end_sec',
       'silence_middle_count', 'silence_middle_mean_sec']

for num_clusters in k_to_test:
    kmeans_best = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
    best_k_labels = kmeans_best.fit_predict(X_scaled)

    clustering_df['cluster'] = best_k_labels
    clustering_df['artist'] = df["id_artist"].apply(lambda x: artist_name_map.get(x))

    cluster_artist_distribution = (
        clustering_df
        .assign(cluster=best_k_labels)
        .groupby(['cluster', 'artist'])
        .size()
        .unstack(fill_value=0)
    )

    # Add totals per cluster
    cluster_artist_distribution['total'] = cluster_artist_distribution.sum(axis=1)
    cluster_artist_distribution['fedez_perc'] = (cluster_artist_distribution['fedez'] / cluster_artist_distribution['total']) * 100
    cluster_artist_distribution['fabri_perc'] = (cluster_artist_distribution['fabri fibra'] / cluster_artist_distribution['total']) * 100
    
    # Normalize features to 0-1 scale
    normalized_df = (clustering_df[numeric_features] - clustering_df[numeric_features].min()) / (clustering_df[numeric_features].max() - clustering_df[numeric_features].min())

    # get data for all clusters
    cluster_data = {}
    for cluster_id in sorted(clustering_df['cluster'].unique()):
        cluster_data[cluster_id] = normalized_df[clustering_df['cluster'] == cluster_id].mean()

    N = len(numeric_features)

    # angles for each cluster
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    fig, ax = plt.subplots(figsize=(12, 12), subplot_kw=dict(projection='polar'))
    colors = ['purple', 'blue', 'green', 'yellow', 'black', 'red']

    # plot clusters
    for idx, (cluster_id, data) in enumerate(cluster_data.items()):
        values = data.tolist()
        values += values[:1]
        
        ax.plot(angles, values, 'o-', linewidth=2, 
                label=f'Cluster {cluster_id}', 
                color=colors[idx], alpha=0.8)
        ax.fill(angles, values, alpha=0.15, color=colors[idx])

    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(numeric_features, size=11)
    ax.set_ylim(0, 1)

    ax.grid(True, linestyle='--', alpha=0.7)
    plt.legend(loc='upper right', fontsize=12)
    plt.title(f'Cluster Profiles. K = {num_clusters}', size=16, y=1.08, fontweight='bold')

    plt.tight_layout()
    plt.show()

    print(f"K = {num_clusters}\n")
    print(cluster_artist_distribution)
    print("-----------------------------")
    print("\n")
# Out:
# K = 2
#
# artist   fabri fibra  fedez  total  fedez_perc  fabri_perc
# cluster
# 0                 81     67    148   45.270270   54.729730
# 1                188    104    292   35.616438   64.383562
# -----------------------------
# K = 3
#
# artist   fabri fibra  fedez  total  fedez_perc  fabri_perc
# cluster
# 0                146     72    218   33.027523   66.972477
# 1                 35      8     43   18.604651   81.395349
# 2                 88     91    179   50.837989   49.162011
# -----------------------------
# K = 4
#
# artist   fabri fibra  fedez  total  fedez_perc  fabri_perc
# cluster
# 0                 90     91    181   50.276243   49.723757
# 1                157     71    228   31.140351   68.859649
# 2                  0      1      1  100.000000    0.000000
# 3                 22      8     30   26.666667   73.333333
# -----------------------------
# K = 6
#
# artist   fabri fibra  fedez  total  fedez_perc  fabri_perc
# cluster
# ...

# %% [markdown]
# We found out thta clusters 3 and 4 are possible outlier songs and made by 1 and 2 songs respectively. We want to remove them from the dataset and run again k means with k = 4 and see what happens.

# %%
clustering_df[clustering_df['cluster'] == 3]
# Out:
#            bpm  centroid_mean  rolloff_mean  flux_mean  rms_mean  zcr_mean  \
# 425  83.354335    2668.543001   5604.124446   1.599295  0.294154   0.10678
#
#      flatness_mean  spectral_complexity_mean  pitch_mean  loudness_mean  \
# 425       0.040693               2682.404653   80.971158      -5.814247
#
#      silence_start_sec  silence_end_sec  silence_middle_count  \
# 425                0.0             3.71                     0
#
#      silence_middle_mean_sec  cluster artist
# 425                      0.0        3  fedez

# %%
clustering_df[clustering_df['cluster'] == 4]
# Out:
#            bpm  centroid_mean  rolloff_mean  flux_mean  rms_mean  zcr_mean  \
# 103  92.285156    1900.819488   3984.455073   1.642677  0.101945  0.088221
# 220  80.749512    1806.435068   3731.298271   1.088045  0.033582  0.075272
#
#      flatness_mean  spectral_complexity_mean  pitch_mean  loudness_mean  \
# 103       0.008192               2025.008043  112.698397     -16.009140
# 220       0.033295               2145.012901  201.108548     -22.283752
#
#      silence_start_sec  silence_end_sec  silence_middle_count  \
# 103              11.94             0.00                    19
# 220               6.73             0.09                    28
#
#      silence_middle_mean_sec  cluster artist
# 103                     0.28        4  fedez
# 220                     1.04        4  fedez

# %%
# remove rows where cluster is 3 or 4
clustering_df = clustering_df[~clustering_df['cluster'].isin([3, 4])]

# drop cluster and artist columns
clustering_df = clustering_df.drop(columns=['cluster', 'artist'])

scaler = StandardScaler()
# apply scaling
X_scaled = scaler.fit_transform(clustering_df.values)

# %%
num_clusters = 4

kmeans_best = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
best_k_labels = kmeans_best.fit_predict(X_scaled)

clustering_df['cluster'] = best_k_labels
clustering_df['artist'] = df["id_artist"].apply(lambda x: artist_name_map.get(x))

cluster_artist_distribution = (
    clustering_df
    .assign(cluster=best_k_labels)
    .groupby(['cluster', 'artist'])
    .size()
    .unstack(fill_value=0)
)

# Add totals per cluster
cluster_artist_distribution['total'] = cluster_artist_distribution.sum(axis=1)
cluster_artist_distribution['fedez_perc'] = (cluster_artist_distribution['fedez'] / cluster_artist_distribution['total']) * 100
cluster_artist_distribution['fabri_perc'] = (cluster_artist_distribution['fabri fibra'] / cluster_artist_distribution['total']) * 100

# Normalize features to 0-1 scale
normalized_df = (clustering_df[numeric_features] - clustering_df[numeric_features].min()) / (clustering_df[numeric_features].max() - clustering_df[numeric_features].min())

# get data for all clusters
cluster_data = {}
for cluster_id in sorted(clustering_df['cluster'].unique()):
    cluster_data[cluster_id] = normalized_df[clustering_df['cluster'] == cluster_id].mean()

N = len(numeric_features)

# angles for each cluster
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]

fig, ax = plt.subplots(figsize=(12, 12), subplot_kw=dict(projection='polar'))
colors = ['purple', 'blue', 'green', 'yellow', 'black', 'red']

# plot clusters
for idx, (cluster_id, data) in enumerate(cluster_data.items()):
    values = data.tolist()
    values += values[:1]
    
    ax.plot(angles, values, 'o-', linewidth=2, 
            label=f'Cluster {cluster_id}', 
            color=colors[idx], alpha=0.8)
    ax.fill(angles, values, alpha=0.15, color=colors[idx])

ax.set_xticks(angles[:-1])
ax.set_xticklabels(numeric_features, size=11)
ax.set_ylim(0, 1)

ax.grid(True, linestyle='--', alpha=0.7)
plt.legend(loc='upper right', fontsize=12)
plt.title(f'Cluster Profiles. K = {num_clusters}', size=16, y=1.08, fontweight='bold')

plt.tight_layout()
plt.show()

print(f"K = {num_clusters}\n")
print(cluster_artist_distribution)
print("-----------------------------")
print("\n")

perplexity=35
n_iter=1000
 
# compute t sne
tsne = TSNE(n_components=2, perplexity=perplexity, max_iter=n_iter, random_state=42)
X_tsne = tsne.fit_transform(X_scaled)

plt.figure(figsize=(12, 8))
scatter = plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=best_k_labels,
                        cmap='viridis', edgecolors='k', alpha=0.6, s=50)
plt.colorbar(scatter, label='Cluster')
plt.xlabel('t-SNE Comp 1')
plt.ylabel('t-SNE Comp 2')
plt.title(f't-SNE k: {num_clusters}', 
            fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# K = 4
#
# artist   fabri fibra  fedez  total  fedez_perc  fabri_perc
# cluster
# 0                 95     37    132   28.030303   71.969697
# 1                 56     48    104   46.153846   53.846154
# 2                107     78    185   42.162162   57.837838
# 3                 11      5     16   31.250000   68.750000
# -----------------------------
