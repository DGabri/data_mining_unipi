# %%
from tslearn.preprocessing import TimeSeriesScalerMeanVariance
from tslearn.clustering import TimeSeriesKMeans, KShape
from tslearn.utils import to_time_series_dataset
import plotly.express as px
import pandas as pd
import numpy as np
import librosa
import time
import os
# Out:
# /home/data/data_mining_unipi/.venv/lib/python3.10/site-packages/tslearn/bases/bases.py:16: UserWarning: h5py not installed, hdf5 features will not be supported.
# Install h5py to use hdf5 features: http://docs.h5py.org/
#   warn(h5py_msg)

# %%
# base path
mp3_base_path = "../fedez_fibra/"
dataset_output_dir = "../timeseries_datasets/"
tracks_list = os.listdir(mp3_base_path)

# %%
# librosa parameters
# hop length: number of samples between the start of two consecutive windows in the signal. https://learnius.com/slp/4+Speech+Signal+Representations/1+Time-Domain/3+Short-Time+Processing/hop+length

sampling_rate         =  22050 # extracted from mp3
song_start_offset_sec = 30 # to skip intro
window_duration_sec   = 60
hop_length = 512 

number_tracks = len(tracks_list)
print(f"Found: {number_tracks} mp3 tracks")
# Out:
# Found: 454 mp3 tracks

# %%
# silence threshold is 20db
# https://audiology-web.s3.amazonaws.com/migrated/NoiseChart_Poster-%208.5x11.pdf_5399b289427535.32730330.pdf

def find_silence_points(data, sampling_rate, top_db=20):
    num_samples = len(data)
    duration = num_samples / sampling_rate
    
    # intervals where db > top_db
    # intervals[i] == (start_i, end_i) are the start and end time (in samples) of non-silent interval i
    intervals = librosa.effects.split(data, top_db=top_db)
    
    if len(intervals) == 0:
        # track is silent
        return {
            'silence_start_sec': duration,
            'silence_end_sec': 0,
            'silence_middle_total_sec': 0,
            'silence_middle_count': 0,
            'silence_middle_mean_sec': 0,
            'is_silent': True
        }
    
    # silence at the beginning
    first_sound = intervals[0][0]
    silence_start = first_sound / sampling_rate
    
    # silence at end, last non silence sample
    last_sound = intervals[-1][1]
    silence_end = (num_samples - last_sound) / sampling_rate
    
    # silence in the middle
    middle_silences = []
    
    for i in range(len(intervals) - 1):
        gap_start = intervals[i][1]
        gap_end = intervals[i + 1][0]
        gap_duration = (gap_end - gap_start) / sampling_rate
        middle_silences.append(gap_duration)
    
    # statistics for silences
    middle_count = len(middle_silences)
    middle_total = sum(middle_silences)
    middle_mean = middle_total / middle_count if middle_count > 0 else 0
    
    return {
        'silence_start_sec': round(silence_start, 2),
        'silence_end_sec': round(silence_end, 2),
        'silence_middle_total_sec': round(middle_total, 2),
        'silence_middle_count': middle_count,
        'silence_middle_mean_sec': round(middle_mean, 2),
        'is_silent': False
    }

# %%
# check if tracks are in the origianl tracks dataset
tracks = pd.read_csv("../original_datasets/tracks.csv")

# parse fname -> artistID - trackID
tracks_info = []

start = time.time()

for i in range(number_tracks):
    
    # :-4 take fname without .mp3
    # split on " - " to get left and right part    
    fname = tracks_list[i]
    splitted_fname = fname[:-4].split(" - ")
    artist_id = splitted_fname[0]
    track_id = splitted_fname[1]
    
    data, sr = librosa.load(mp3_base_path+fname)
    num_samples = data.shape[0]
    
    # basic track info to expand with features
    track_info = {"id": track_id, "id_artist": artist_id, "num_samples": num_samples, "sr": sr}

    # duration ms
    duration_ms = librosa.get_duration(y=data, sr=sr) * 1000
    bpms, _ = librosa.beat.beat_track(y=data, sr=sr)
    track_info['duration_ms'] = duration_ms
    track_info['bpm'] = bpms[0]
    
    centroid = librosa.feature.spectral_centroid(y=data, sr=sr, hop_length=hop_length)[0]
    track_info['centroid_mean'] = np.mean(centroid)
    track_info['centroid_std'] = np.std(centroid)
    
    rolloff = librosa.feature.spectral_rolloff(y=data, sr=sr, hop_length=hop_length)[0]
    track_info['rolloff_mean'] = np.mean(rolloff)
    track_info['rolloff_std'] = np.std(rolloff)
    
    flux = librosa.onset.onset_strength(y=data, sr=sr, hop_length=hop_length)
    track_info['flux_mean'] = np.mean(flux)
    track_info['flux_std'] = np.std(flux)
    
    rms = librosa.feature.rms(y=data, hop_length=hop_length)[0]
    track_info['rms_mean'] = np.mean(rms)
    track_info['rms_std'] = np.std(rms)
    
    zcr = librosa.feature.zero_crossing_rate(y=data, hop_length=hop_length)[0]
    track_info['zcr_mean'] = np.mean(zcr)
    track_info['zcr_std'] = np.std(zcr)
    
    flatness = librosa.feature.spectral_flatness(y=data, hop_length=hop_length)[0]
    track_info['flatness_mean'] = np.mean(flatness)
    track_info['flatness_std'] = np.std(flatness)
    
    spec_bw = librosa.feature.spectral_bandwidth(y=data, sr=sr, hop_length=hop_length)[0]
    track_info['spectral_complexity_mean'] = np.mean(spec_bw)
    track_info['spectral_complexity_std'] = np.std(spec_bw)
    
    # extract fundamental frequency of signal
    # fmin = lowest pitch to detect 50 hz below male voice
    # fmax = highes pitch to detect 500 hz above female voice
    # hop length = how often to estimate pitch
    f0 = librosa.yin(data, fmin=50, fmax=500, sr=sr, hop_length=hop_length)
    
    # Filter out zeros and very low values (unvoiced segments)
    f0_voiced = f0[f0 > 50]
    track_info['pitch_mean'] = np.mean(f0_voiced) if len(f0_voiced) > 0 else 0
    track_info['pitch_std'] = np.std(f0_voiced) if len(f0_voiced) > 0 else 0
    
    loudness_db = librosa.amplitude_to_db(rms, ref=np.max)
    track_info['loudness_mean'] = np.mean(loudness_db)
    track_info['loudness_std'] = np.std(loudness_db)

    # compute silence points and save
    silence_stats = find_silence_points(data, sr, top_db=20)
    track_info.update(silence_stats)
    
    tracks_info.append(track_info)
    print(f"[{i}/{number_tracks}] {track_info}\n")

end = time.time()

print(f"Took: {end-start:.2f}")
# Out:
# [0/454] {'id': 'TR597348', 'id_artist': 'ART25707984', 'num_samples': 5209089, 'sr': 22050, 'duration_ms': 236239.86394557822, 'bpm': np.float64(103.359375), 'centroid_mean': np.float64(1848.4146419965525), 'centroid_std': np.float64(568.8260419797531), 'rolloff_mean': np.float64(3673.5083715640358), 'rolloff_std': np.float64(1572.2047758565616), 'flux_mean': np.float32(1.8687936), 'flux_std': np.float32(1.6797049), 'rms_mean': np.float32(0.23188205), 'rms_std': np.float32(0.09516897), 'zcr_mean': np.float64(0.07867307470823096), 'zcr_std': np.float64(0.044399932326326136), 'flatness_mean': np.float32(0.008160612), 'flatness_std': np.float32(0.033699267), 'spectral_complexity_mean': np.float64(2213.814011680665), 'spectral_complexity_std': np.float64(411.6160097143482), 'pitch_mean': np.float64(167.3109638491438), 'pitch_std': np.float64(89.48473482958073), 'loudness_mean': np.float32(-8.652038), 'loudness_std': np.float32(6.672208), 'silence_start_sec': np.float64(0.28), 'silence_end_sec': np.float64(2.51), 'silence_middle_total_sec': np.float64(9.75), 'silence_middle_count': 63, 'silence_middle_mean_sec': np.float64(0.15), 'is_silent': False}
#
# [1/454] {'id': 'TR745549', 'id_artist': 'ART07024718', 'num_samples': 4191233, 'sr': 22050, 'duration_ms': 190078.5941043084, 'bpm': np.float64(92.28515625), 'centroid_mean': np.float64(3149.761209106852), 'centroid_std': np.float64(947.5102866434038), 'rolloff_mean': np.float64(6740.413351817287), 'rolloff_std': np.float64(1583.4949134687067), 'flux_mean': np.float32(1.4388834), 'flux_std': np.float32(1.1734507), 'rms_mean': np.float32(0.21165414), 'rms_std': np.float32(0.09080922), 'zcr_mean': np.float64(0.15118528230731648), 'zcr_std': np.float64(0.0844913933108297), 'flatness_mean': np.float32(0.07514642), 'flatness_std': np.float32(0.116469935), 'spectral_complexity_mean': np.float64(2882.9889823869444), 'spectral_complexity_std': np.float64(451.53586025849444), 'pitch_mean': np.float64(107.7362053512081), 'pitch_std': np.float64(83.45663547224127), 'loudness_mean': np.float32(-7.844501), 'loudness_std': np.float32(10.776189), 'silence_start_sec': np.float64(0.7), 'silence_end_sec': np.float64(5.36), 'silence_middle_total_sec': np.float64(5.62), 'silence_middle_count': 22, 'silence_middle_mean_sec': np.float64(0.26), 'is_silent': False}
#
# [2/454] {'id': 'TR324941', 'id_artist': 'ART25707984', 'num_samples': 5180929, 'sr': 22050, 'duration_ms': 234962.7664399093, 'bpm': np.float64(161.4990234375), 'centroid_mean': np.float64(2611.5075378172587), 'centroid_std': np.float64(865.7664117722004), 'rolloff_mean': np.float64(5765.5566285627165), 'rolloff_std': np.float64(1758.2196424328743), 'flux_mean': np.float32(1.6200099), 'flux_std': np.float32(1.6851287), 'rms_mean': np.float32(0.12663509), 'rms_std': np.float32(0.058099452), 'zcr_mean': np.float64(0.11174519052618577), 'zcr_std': np.float64(0.06282164821110647), 'flatness_mean': np.float32(0.0488186), 'flatness_std': np.float32(0.12994385), 'spectral_complexity_mean': np.float64(2665.1837137308466), 'spectral_complexity_std': np.float64(544.7137121805163), 'pitch_mean': np.float64(154.34609669247712), 'pitch_std': np.float64(116.42457161646348), 'loudness_mean': np.float32(-9.529303), 'loudness_std': np.float32(11.598136), 'silence_start_sec': np.float64(0.67), 'silence_end_sec': np.float64(7.85), 'silence_middle_total_sec': np.float64(8.99), 'silence_middle_count': 50, 'silence_middle_mean_sec': np.float64(0.18), 'is_silent': False}
#
# [3/454] {'id': 'TR496653', 'id_artist': 'ART07024718', 'num_samples': 4821130, 'sr': 22050, 'duration_ms': 218645.35147392293, 'bpm': np.float64(92.28515625), 'centroid_mean': np.float64(2095.548019815926), 'centroid_std': np.float64(1073.5606066935325), 'rolloff_mean': np.float64(4834.615695123347), 'rolloff_std': np.float64(2436.2102395841475), 'flux_mean': np.float32(1.2652555), 'flux_std': np.float32(1.2944472), 'rms_mean': np.float32(0.24098176), 'rms_std': np.float32(0.128493), 'zcr_mean': np.float64(0.0730239983208559), 'zcr_std': np.float64(0.05666333246661474), 'flatness_mean': np.float32(0.05921529), 'flatness_std': np.float32(0.20266677), 'spectral_complexity_mean': np.float64(2436.258817260624), 'spectral_complexity_std': np.float64(925.90303023153), 'pitch_mean': np.float64(124.67904223325868), 'pitch_std': np.float64(121.52479714627326), 'loudness_mean': np.float32(-13.161711), 'loudness_std': np.float32(16.758081), 'silence_start_sec': np.float64(0.49), 'silence_end_sec': np.float64(9.94), 'silence_middle_total_sec': np.float64(8.71), 'silence_middle_count': 50, 'silence_middle_mean_sec': np.float64(0.17), 'is_silent': False}
#
# [4/454] {'id': 'TR910855', 'id_artist': 'ART25707984', 'num_samples': 4372368, 'sr': 22050, 'duration_ms': 198293.3333333333, 'bpm': np.float64(184.5703125), 'centroid_mean': np.float64(2820.269972471521), 'centroid_std': np.float64(974.6123588365302), 'rolloff_mean': np.float64(6151.250700403432), 'rolloff_std': np.float64(1776.8671663305), 'flux_mean': np.float32(1.7428087), 'flux_std': np.float32(1.71325), 'rms_mean': np.float32(0.2393618), 'rms_std': np.float32(0.11247109), 'zcr_mean': np.float64(0.11965898071574942), 'zcr_std': np.float64(0.07950582493407955), 'flatness_mean': np.float32(0.03598413), 'flatness_std': np.float32(0.044357892), 'spectral_complexity_mean': np.float64(2778.6218733943965), 'spectral_complexity_std': np.float64(492.5713754825164), 'pitch_mean': np.float64(144.05263911734286), 'pitch_std': np.float64(93.21254052363703), 'loudness_mean': np.float32(-8.4867735), 'loudness_std': np.float32(9.887979), 'silence_start_sec': np.float64(0.07), 'silence_end_sec': np.float64(0.48), 'silence_middle_total_sec': np.float64(15.67), 'silence_middle_count': 20, 'silence_middle_mean_sec': np.float64(0.78), 'is_silent': False}
#
# [5/454] {'id': 'TR686371', 'id_artist': 'ART25707984', 'num_samples': 5472001, 'sr': 22050, 'duration_ms': 248163.3106575964, 'bpm': np.float64(107.666015625), 'centroid_mean': np.float64(2437.7430484997985), 'centroid_std': np.float64(1049.0614797000555), 'rolloff_mean': np.float64(5470.30696983109), 'rolloff_std': np.float64(2097.687095251907), 'flux_mean': np.float32(1.8288486), 'flux_std': np.float32(2.0322607), 'rms_mean': np.float32(0.06925703), 'rms_std': np.float32(0.03826824), 'zcr_mean': np.float64(0.09901263756666355), 'zcr_std': np.float64(0.07606050121906067), 'flatness_mean': np.float32(0.037813254), 'flatness_std': np.float32(0.09048398), 'spectral_complexity_mean': np.float64(2582.4215904219195), 'spectral_complexity_std': np.float64(666.6030724636865), 'pitch_mean': np.float64(128.83824593470038), 'pitch_std': np.float64(92.25933694628571), 'loudness_mean': np.float32(-9.49217), 'loudness_std': np.float32(7.977876), 'silence_start_sec': np.float64(0.72), 'silence_end_sec': np.float64(1.2), 'silence_middle_total_sec': np.float64(6.64), 'silence_middle_count': 88, 'silence_middle_mean_sec': np.float64(0.08), 'is_silent': False}
#
# [6/454] {'id': 'TR944243', 'id_artist': 'ART07024718', 'num_samples': 4631553, 'sr': 22050, 'duration_ms': 210047.7551020408, 'bpm': np.float64(92.28515625), 'centroid_mean': np.float64(2537.6364264897934), 'centroid_std': np.float64(1060.5126221010605), 'rolloff_mean': np.float64(5415.787427591674), 'rolloff_std': np.float64(2101.1434766908083), 'flux_mean': np.float32(1.5611576), 'flux_std': np.float32(1.5929489), 'rms_mean': np.float32(0.24492732), 'rms_std': np.float32(0.08200528), 'zcr_mean': np.float64(0.11678346844948602), 'zcr_std': np.float64(0.07741431080888232), 'flatness_mean': np.float32(0.034969628), 'flatness_std': np.float32(0.07090446), 'spectral_complexity_mean': np.float64(2549.827199226999), 'spectral_complexity_std': np.float64(633.4585355521109), 'pitch_mean': np.float64(140.3480437738727), 'pitch_std': np.float64(109.82878725588209), 'loudness_mean': np.float32(-6.0245395), 'loudness_std': np.float32(6.164553), 'silence_start_sec': np.float64(0.44), 'silence_end_sec': np.float64(1.63), 'silence_middle_total_sec': np.float64(1.42), 'silence_middle_count': 6, 'silence_middle_mean_sec': np.float64(0.24), 'is_silent': False}
#
# [7/454] {'id': 'TR808663', 'id_artist': 'ART07024718', 'num_samples': 5263617, 'sr': 22050, 'duration_ms': 238712.78911564624, 'bpm': np.float64(89.10290948275862), 'centroid_mean': np.float64(2300.2767806838146), 'centroid_std': np.float64(1077.799247471994), 'rolloff_mean': np.float64(4887.27262934965), 'rolloff_std': np.float64(2095.991451326359), 'flux_mean': np.float32(1.8751968), 'flux_std': np.float32(2.1131992), 'rms_mean': np.float32(0.106649145), 'rms_std': np.float32(0.049964253), 'zcr_mean': np.float64(0.0919109545216905), 'zcr_std': np.float64(0.08249687565408484), 'flatness_mean': np.float32(0.02586952), 'flatness_std': np.float32(0.041799165), 'spectral_complexity_mean': np.float64(2489.0266038186896), 'spectral_complexity_std': np.float64(537.0342450310983), 'pitch_mean': np.float64(114.16847116067675), 'pitch_std': np.float64(70.81760545630489), 'loudness_mean': np.float32(-8.000886), 'loudness_std': np.float32(6.271071), 'silence_start_sec': np.float64(0.19), 'silence_end_sec': np.float64(1.03), 'silence_middle_total_sec': np.float64(2.86), 'silence_middle_count': 27, 'silence_middle_mean_sec': np.float64(0.11), 'is_silent': False}
#
# [8/454] {'id': 'TR475897', 'id_artist': 'ART25707984', 'num_samples': 4829185, 'sr': 22050, 'duration_ms': 219010.6575963719, 'bpm': np.float64(161.4990234375), 'centroid_mean': np.float64(2860.1003007053237), 'centroid_std': np.float64(1127.1288980786637), 'rolloff_mean': np.float64(6344.145495906989), 'rolloff_std': np.float64(1928.1385943513012), 'flux_mean': np.float32(1.9586593), 'flux_std': np.float32(2.2324328), 'rms_mean': np.float32(0.17425734), 'rms_std': np.float32(0.10062724), 'zcr_mean': np.float64(0.11165614771612954), 'zcr_std': np.float64(0.0891193125594652), 'flatness_mean': np.float32(0.034384347), 'flatness_std': np.float32(0.04670702), 'spectral_complexity_mean': np.float64(2861.5228582319774), 'spectral_complexity_std': np.float64(510.9589219312756), 'pitch_mean': np.float64(143.8423152736964), 'pitch_std': np.float64(93.33978287720858), 'loudness_mean': np.float32(-10.898841), 'loudness_std': np.float32(7.8589783), 'silence_start_sec': np.float64(0.16), 'silence_end_sec': np.float64(0.44), 'silence_middle_total_sec': np.float64(16.93), 'silence_middle_count': 150, 'silence_middle_mean_sec': np.float64(0.11), 'is_silent': False}
#
# [9/454] {'id': 'TR735029', 'id_artist': 'ART25707984', 'num_samples': 5775617, 'sr': 22050, 'duration_ms': 261932.74376417237, 'bpm': np.float64(99.38401442307692), 'centroid_mean': np.float64(2331.9007829461507), 'centroid_std': np.float64(714.4448713044582), 'rolloff_mean': np.float64(5417.7527609683875), 'rolloff_std': np.float64(1547.1496371624592), 'flux_mean': np.float32(1.7550136), 'flux_std': np.float32(2.0885897), 'rms_mean': np.float32(0.24458112), 'rms_std': np.float32(0.11552087), 'zcr_mean': np.float64(0.08411933297690807), 'zcr_std': np.float64(0.04577508693374834), 'flatness_mean': np.float32(0.02115736), 'flatness_std': np.float32(0.031411763), 'spectral_complexity_mean': np.float64(2659.2301370036485), 'spectral_complexity_std': np.float64(469.5043093357169), 'pitch_mean': np.float64(108.82505247253745), 'pitch_std': np.float64(99.79982111199367), 'loudness_mean': np.float32(-8.078473), 'loudness_std': np.float32(6.833133), 'silence_start_sec': np.float64(0.26), 'silence_end_sec': np.float64(0.0), 'silence_middle_total_sec': np.float64(11.56), 'silence_middle_count': 61, 'silence_middle_mean_sec': np.float64(0.19), 'is_silent': False}
#
# [10/454] {'id': 'TR788528', 'id_artist': 'ART07024718', 'num_samples': 3023790, 'sr': 22050, 'duration_ms': 137133.3333333333, 'bpm': np.float64(172.265625), 'centroid_mean': np.float64(2119.829976168027), 'centroid_std': np.float64(1084.0513128482175), 'rolloff_mean': np.float64(4829.825270381815), 'rolloff_std': np.float64(2346.355353759705), 'flux_mean': np.float32(1.3265281), 'flux_std': np.float32(1.5734729), 'rms_mean': np.float32(0.30046508), 'rms_std': np.float32(0.15302147), 'zcr_mean': np.float64(0.06538338924398916), 'zcr_std': np.float64(0.06161134823596094), 'flatness_mean': np.float32(0.0155664245), 'flatness_std': np.float32(0.049391493), 'spectral_complexity_mean': np.float64(2466.10267858033), 'spectral_complexity_std': np.float64(736.6147706678), 'pitch_mean': np.float64(153.13328436741483), 'pitch_std': np.float64(119.11458703114567), 'loudness_mean': np.float32(-8.466489), 'loudness_std': np.float32(12.512796), 'silence_start_sec': np.float64(0.19), 'silence_end_sec': np.float64(8.22), 'silence_middle_total_sec': np.float64(5.8), 'silence_middle_count': 15, 'silence_middle_mean_sec': np.float64(0.39), 'is_silent': False}
#
# [11/454] {'id': 'TR831827', 'id_artist': 'ART25707984', 'num_samples': 6953217, 'sr': 22050, 'duration_ms': 315338.6394557823, 'bpm': np.float64(89.10290948275862), 'centroid_mean': np.float64(2848.1572045989083), 'centroid_std': np.float64(996.4634676509182), 'rolloff_mean': np.float64(6197.134089991302), 'rolloff_std': np.float64(1589.3150264029216), 'flux_mean': np.float32(1.7217805), 'flux_std': np.float32(1.9604042), 'rms_mean': np.float32(0.24609055), 'rms_std': np.float32(0.13356626), 'zcr_mean': np.float64(0.131716464810673), 'zcr_std': np.float64(0.09214033310632067), 'flatness_mean': np.float32(0.04823506), 'flatness_std': np.float32(0.056974426), 'spectral_complexity_mean': np.float64(2794.7793268640794), 'spectral_complexity_std': np.float64(380.68798288347415), 'pitch_mean': np.float64(130.9079640668459), 'pitch_std': np.float64(91.02151460510427), 'loudness_mean': np.float32(-9.221471), 'loudness_std': np.float32(6.4423532), 'silence_start_sec': np.float64(1.86), 'silence_end_sec': np.float64(5.17), 'silence_middle_total_sec': np.float64(5.87), 'silence_middle_count': 78, 'silence_middle_mean_sec': np.float64(0.08), 'is_silent': False}
#
# [12/454] {'id': 'TR273414', 'id_artist': 'ART25707984', 'num_samples': 5360796, 'sr': 22050, 'duration_ms': 243120.0, 'bpm': np.float64(123.046875), 'centroid_mean': np.float64(1926.0724684131665), 'centroid_std': np.float64(1091.1563158671497), 'rolloff_mean': np.float64(4384.989732617169), 'rolloff_std': np.float64(2572.935786799982), 'flux_mean': np.float32(1.6576122), 'flux_std': np.float32(1.9878631), 'rms_mean': np.float32(0.25535032), 'rms_std': np.float32(0.123511784), 'zcr_mean': np.float64(0.05243975548538821), 'zcr_std': np.float64(0.0547722366877455), 'flatness_mean': np.float32(0.012808085), 'flatness_std': np.float32(0.03423353), 'spectral_complexity_mean': np.float64(2364.6816410528145), 'spectral_complexity_std': np.float64(806.0517570765218), 'pitch_mean': np.float64(96.74635739024305), 'pitch_std': np.float64(67.66462101277028), 'loudness_mean': np.float32(-10.346212), 'loudness_std': np.float32(13.41489), 'silence_start_sec': np.float64(9.98), 'silence_end_sec': np.float64(4.12), 'silence_middle_total_sec': np.float64(17.28), 'silence_middle_count': 55, 'silence_middle_mean_sec': np.float64(0.31), 'is_silent': False}
#
# [13/454] {'id': 'TR946148', 'id_artist': 'ART07024718', 'num_samples': 6249217, 'sr': 22050, 'duration_ms': 283411.201814059, 'bpm': np.float64(123.046875), 'centroid_mean': np.float64(2577.696912929803), 'centroid_std': np.float64(1136.5699933935475), 'rolloff_mean': np.float64(5693.546676823258), 'rolloff_std': np.float64(2335.2654196836415), 'flux_mean': np.float32(1.2768437), 'flux_std': np.float32(1.2152702), 'rms_mean': np.float32(0.19765162), 'rms_std': np.float32(0.11798093), 'zcr_mean': np.float64(0.10635650499754219), 'zcr_std': np.float64(0.08179567952839949), 'flatness_mean': np.float32(0.031867106), 'flatness_std': np.float32(0.05554397), 'spectral_complexity_mean': np.float64(2644.306328763625), 'spectral_complexity_std': np.float64(728.0371740468037), 'pitch_mean': np.float64(108.73472848017046), 'pitch_std': np.float64(89.87855780822056), 'loudness_mean': np.float32(-13.371595), 'loudness_std': np.float32(9.591078), 'silence_start_sec': np.float64(0.21), 'silence_end_sec': np.float64(0.15), 'silence_middle_total_sec': np.float64(38.17), 'silence_middle_count': 66, 'silence_middle_mean_sec': np.float64(0.58), 'is_silent': False}
#
# [14/454] {'id': 'TR148805', 'id_artist': 'ART25707984', 'num_samples': 5030145, 'sr': 22050, 'duration_ms': 228124.48979591837, 'bpm': np.float64(129.19921875), 'centroid_mean': np.float64(2645.950616342566), 'centroid_std': np.float64(1056.0510323716767), 'rolloff_mean': np.float64(5651.582575441317), 'rolloff_std': np.float64(2015.4092838957029), 'flux_mean': np.float32(1.7413406), 'flux_std': np.float32(1.7157118), 'rms_mean': np.float32(0.07640046), 'rms_std': np.float32(0.044062532), 'zcr_mean': np.float64(0.12002305979643765), 'zcr_std': np.float64(0.07664218281741558), 'flatness_mean': np.float32(0.03313914), 'flatness_std': np.float32(0.04334837), 'spectral_complexity_mean': np.float64(2564.572762729817), 'spectral_complexity_std': np.float64(611.9907360015935), 'pitch_mean': np.float64(184.94529107536212), 'pitch_std': np.float64(108.08417385101752), 'loudness_mean': np.float32(-10.086743), 'loudness_std': np.float32(8.948701), 'silence_start_sec': np.float64(17.14), 'silence_end_sec': np.float64(0.06), 'silence_middle_total_sec': np.float64(1.72), 'silence_middle_count': 43, 'silence_middle_mean_sec': np.float64(0.04), 'is_silent': False}
#
# [15/454] {'id': 'TR705159', 'id_artist': 'ART25707984', 'num_samples': 5839805, 'sr': 22050, 'duration_ms': 264843.7641723356, 'bpm': np.float64(129.19921875), 'centroid_mean': np.float64(2376.1778997617203), 'centroid_std': np.float64(1046.4437960895493), 'rolloff_mean': np.float64(5141.892354404343), 'rolloff_std': np.float64(2158.1903598884537), 'flux_mean': np.float32(1.7740821), 'flux_std': np.float32(2.1371264), 'rms_mean': np.float32(0.20755656), 'rms_std': np.float32(0.08217508), 'zcr_mean': np.float64(0.08671602733758547), 'zcr_std': np.float64(0.06775180264824252), 'flatness_mean': np.float32(0.02307556), 'flatness_std': np.float32(0.036217563), 'spectral_complexity_mean': np.float64(2503.03082897038), 'spectral_complexity_std': np.float64(668.2463986133774), 'pitch_mean': np.float64(97.66270094240879), 'pitch_std': np.float64(63.65196564295425), 'loudness_mean': np.float32(-7.5772567), 'loudness_std': np.float32(7.6731033), 'silence_start_sec': np.float64(0.07), 'silence_end_sec': np.float64(1.25), 'silence_middle_total_sec': np.float64(13.65), 'silence_middle_count': 30, 'silence_middle_mean_sec': np.float64(0.46), 'is_silent': False}
#
# [16/454] {'id': 'TR903036', 'id_artist': 'ART25707984', 'num_samples': 6829569, 'sr': 22050, 'duration_ms': 309731.02040816325, 'bpm': np.float64(99.38401442307692), 'centroid_mean': np.float64(3019.9676556029153), 'centroid_std': np.float64(971.7905112847834), 'rolloff_mean': np.float64(6103.39110962097), 'rolloff_std': np.float64(1697.5376663562095), 'flux_mean': np.float32(1.4539174), 'flux_std': np.float32(1.5091738), 'rms_mean': np.float32(0.059236348), 'rms_std': np.float32(0.03545338), 'zcr_mean': np.float64(0.16338512872470015), 'zcr_std': np.float64(0.10294120855939533), 'flatness_mean': np.float32(0.06259948), 'flatness_std': np.float32(0.067641996), 'spectral_complexity_mean': np.float64(2697.5255351808482), 'spectral_complexity_std': np.float64(424.4158070105551), 'pitch_mean': np.float64(145.59467264837627), 'pitch_std': np.float64(109.04396709794855), 'loudness_mean': np.float32(-11.152323), 'loudness_std': np.float32(13.594208), 'silence_start_sec': np.float64(0.7), 'silence_end_sec': np.float64(20.53), 'silence_middle_total_sec': np.float64(29.02), 'silence_middle_count': 74, 'silence_middle_mean_sec': np.float64(0.39), 'is_silent': False}
#
# [17/454] {'id': 'TR402241', 'id_artist': 'ART25707984', 'num_samples': 2727936, 'sr': 22050, 'duration_ms': 123715.91836734694, 'bpm': np.float64(123.046875), 'centroid_mean': np.float64(2831.0656654488726), 'centroid_std': np.float64(651.7383536254271), 'rolloff_mean': np.float64(6215.018226478936), 'rolloff_std': np.float64(1071.7883087833416), 'flux_mean': np.float32(1.4519395), 'flux_std': np.float32(1.1570665), 'rms_mean': np.float32(0.13168094), 'rms_std': np.float32(0.047946844), 'zcr_mean': np.float64(0.12428237591480577), 'zcr_std': np.float64(0.059252624358329176), 'flatness_mean': np.float32(0.021868967), 'flatness_std': np.float32(0.047076423), 'spectral_complexity_mean': np.float64(2761.70001373788), 'spectral_complexity_std': np.float64(286.81036565751344), 'pitch_mean': np.float64(174.02893954450786), 'pitch_std': np.float64(121.69764402125077), 'loudness_mean': np.float32(-8.250379), 'loudness_std': np.float32(5.616131), 'silence_start_sec': np.float64(0.28), 'silence_end_sec': np.float64(0.0), 'silence_middle_total_sec': np.float64(2.51), 'silence_middle_count': 24, 'silence_middle_mean_sec': np.float64(0.1), 'is_silent': False}
#
# [18/454] {'id': 'TR943904', 'id_artist': 'ART07024718', 'num_samples': 3235764, 'sr': 22050, 'duration_ms': 146746.66666666666, 'bpm': np.float64(103.359375), 'centroid_mean': np.float64(2394.0867056164993), 'centroid_std': np.float64(1236.4143353512636), 'rolloff_mean': np.float64(5268.2548735413375), 'rolloff_std': np.float64(2519.810749830211), 'flux_mean': np.float32(1.708595), 'flux_std': np.float32(2.044109), 'rms_mean': np.float32(0.24348046), 'rms_std': np.float32(0.115483396), 'zcr_mean': np.float64(0.08537188179885284), 'zcr_std': np.float64(0.07563607969059277), 'flatness_mean': np.float32(0.02584463), 'flatness_std': np.float32(0.05989259), 'spectral_complexity_mean': np.float64(2593.9414174357275), 'spectral_complexity_std': np.float64(750.6145739859916), 'pitch_mean': np.float64(126.21693914607701), 'pitch_std': np.float64(123.79886226088776), 'loudness_mean': np.float32(-9.865379), 'loudness_std': np.float32(11.783318), 'silence_start_sec': np.float64(4.99), 'silence_end_sec': np.float64(4.99), 'silence_middle_total_sec': np.float64(5.13), 'silence_middle_count': 7, 'silence_middle_mean_sec': np.float64(0.73), 'is_silent': False}
#
# [19/454] {'id': 'TR300734', 'id_artist': 'ART07024718', 'num_samples': 3484673, 'sr': 22050, 'duration_ms': 158035.05668934243, 'bpm': np.float64(161.4990234375), 'centroid_mean': np.float64(2910.354742202682), 'centroid_std': np.float64(1062.3235771947866), 'rolloff_mean': np.float64(6713.558929026416), 'rolloff_std': np.float64(1742.95744249566), 'flux_mean': np.float32(1.6004808), 'flux_std': np.float32(1.4323952), 'rms_mean': np.float32(0.28244722), 'rms_std': np.float32(0.08908441), 'zcr_mean': np.float64(0.11605004212116204), 'zcr_std': np.float64(0.09050082753220065), 'flatness_mean': np.float32(0.037270825), 'flatness_std': np.float32(0.05236443), 'spectral_complexity_mean': np.float64(3020.844132604928), 'spectral_complexity_std': np.float64(442.06314831385185), 'pitch_mean': np.float64(137.1342040848861), 'pitch_std': np.float64(85.4355456972599), 'loudness_mean': np.float32(-6.6208115), 'loudness_std': np.float32(4.601858), 'silence_start_sec': np.float64(0.05), 'silence_end_sec': np.float64(0.49), 'silence_middle_total_sec': np.float64(0.26), 'silence_middle_count': 4, 'silence_middle_mean_sec': np.float64(0.06), 'is_silent': False}
#
# [20/454] {'id': 'TR368909', 'id_artist': 'ART25707984', 'num_samples': 4881870, 'sr': 22050, 'duration_ms': 221400.0, 'bpm': np.float64(117.45383522727273), 'centroid_mean': np.float64(2248.994937173217), 'centroid_std': np.float64(827.1375723135684), 'rolloff_mean': np.float64(4956.951263539755), 'rolloff_std': np.float64(1782.0186075347629), 'flux_mean': np.float32(1.6305679), 'flux_std': np.float32(1.6724485), 'rms_mean': np.float32(0.19558068), 'rms_std': np.float32(0.11637053), 'zcr_mean': np.float64(0.10376393918786052), 'zcr_std': np.float64(0.05991204070003295), 'flatness_mean': np.float32(0.027904866), 'flatness_std': np.float32(0.04552349), 'spectral_complexity_mean': np.float64(2461.260071357235), 'spectral_complexity_std': np.float64(481.58256173333854), 'pitch_mean': np.float64(127.97116925984866), 'pitch_std': np.float64(92.9213192164347), 'loudness_mean': np.float32(-11.149039), 'loudness_std': np.float32(6.6364207), 'silence_start_sec': np.float64(0.12), 'silence_end_sec': np.float64(0.39), 'silence_middle_total_sec': np.float64(23.36), 'silence_middle_count': 60, 'silence_middle_mean_sec': np.float64(0.39), 'is_silent': False}
#
# [21/454] {'id': 'TR503521', 'id_artist': 'ART25707984', 'num_samples': 5990145, 'sr': 22050, 'duration_ms': 271661.90476190473, 'bpm': np.float64(117.45383522727273), 'centroid_mean': np.float64(1850.4289110804962), 'centroid_std': np.float64(991.4592240824707), 'rolloff_mean': np.float64(4101.350060096154), 'rolloff_std': np.float64(2212.119870967772), 'flux_mean': np.float32(1.515795), 'flux_std': np.float32(1.6758335), 'rms_mean': np.float32(0.22129662), 'rms_std': np.float32(0.061621886), 'zcr_mean': np.float64(0.06047743055555556), 'zcr_std': np.float64(0.043741329983399836), 'flatness_mean': np.float32(0.015880464), 'flatness_std': np.float32(0.0653469), 'spectral_complexity_mean': np.float64(2161.250645736662), 'spectral_complexity_std': np.float64(797.8993772830481), 'pitch_mean': np.float64(86.16693379354969), 'pitch_std': np.float64(61.73592501919744), 'loudness_mean': np.float32(-7.4013343), 'loudness_std': np.float32(7.3390856), 'silence_start_sec': np.float64(0.19), 'silence_end_sec': np.float64(6.05), 'silence_middle_total_sec': np.float64(1.02), 'silence_middle_count': 2, 'silence_middle_mean_sec': np.float64(0.51), 'is_silent': False}
#
# [22/454] {'id': 'TR539870', 'id_artist': 'ART25707984', 'num_samples': 5115905, 'sr': 22050, 'duration_ms': 232013.8321995465, 'bpm': np.float64(123.046875), 'centroid_mean': np.float64(3483.0651903876974), 'centroid_std': np.float64(805.8243469967204), 'rolloff_mean': np.float64(6887.793555097944), 'rolloff_std': np.float64(1120.9875920424374), 'flux_mean': np.float32(1.5916893), 'flux_std': np.float32(1.55892), 'rms_mean': np.float32(0.28407583), 'rms_std': np.float32(0.08457961), 'zcr_mean': np.float64(0.17673782780759031), 'zcr_std': np.float64(0.08089026327839778), 'flatness_mean': np.float32(0.073480815), 'flatness_std': np.float32(0.06707805), 'spectral_complexity_mean': np.float64(2869.5503932507213), 'spectral_complexity_std': np.float64(331.3316535895142), 'pitch_mean': np.float64(151.98204899755092), 'pitch_std': np.float64(100.55643809449667), 'loudness_mean': np.float32(-6.026359), 'loudness_std': np.float32(6.008211), 'silence_start_sec': np.float64(0.0), 'silence_end_sec': np.float64(3.76), 'silence_middle_total_sec': np.float64(0.49), 'silence_middle_count': 8, 'silence_middle_mean_sec': np.float64(0.06), 'is_silent': False}
#
# [23/454] {'id': 'TR955916', 'id_artist': 'ART25707984', 'num_samples': 4454401, 'sr': 22050, 'duration_ms': 202013.65079365077, 'bpm': np.float64(99.38401442307692), 'centroid_mean': np.float64(3019.323491843315), 'centroid_std': np.float64(826.0304281250159), 'rolloff_mean': np.float64(6307.329109418996), 'rolloff_std': np.float64(1319.7623660946497), 'flux_mean': np.float32(1.4981861), 'flux_std': np.float32(1.6211376), 'rms_mean': np.float32(0.29144806), 'rms_std': np.float32(0.09403303), 'zcr_mean': np.float64(0.13959596732774968), 'zcr_std': np.float64(0.07436804173091409), 'flatness_mean': np.float32(0.044156715), 'flatness_std': np.float32(0.04393304), 'spectral_complexity_mean': np.float64(2782.8787521371387), 'spectral_complexity_std': np.float64(380.3992821662112), 'pitch_mean': np.float64(118.7484526377819), 'pitch_std': np.float64(82.28549728325314), 'loudness_mean': np.float32(-6.5028534), 'loudness_std': np.float32(3.7522388), 'silence_start_sec': np.float64(0.05), 'silence_end_sec': np.float64(0.21), 'silence_middle_total_sec': np.float64(0.72), 'silence_middle_count': 5, 'silence_middle_mean_sec': np.float64(0.14), 'is_silent': False}
#
# [24/454] {'id': 'TR636326', 'id_artist': 'ART07024718', 'num_samples': 3770881, 'sr': 22050, 'duration_ms': 171015.0113378685, 'bpm': np.float64(92.28515625), 'centroid_mean': np.float64(2214.8938714180476), 'centroid_std': np.float64(1026.1911928099948), 'rolloff_mean': np.float64(4831.222311284534), 'rolloff_std': np.float64(2249.447063720992), 'flux_mean': np.float32(1.8838333), 'flux_std': np.float32(2.2827692), 'rms_mean': np.float32(0.2059356), 'rms_std': np.float32(0.08268785), 'zcr_mean': np.float64(0.07750937850003393), 'zcr_std': np.float64(0.06638294208646968), 'flatness_mean': np.float32(0.019090185), 'flatness_std': np.float32(0.04183403), 'spectral_complexity_mean': np.float64(2562.1098786570565), 'spectral_complexity_std': np.float64(588.44438567734), 'pitch_mean': np.float64(84.40049802846855), 'pitch_std': np.float64(54.21380211885589), 'loudness_mean': np.float32(-8.335086), 'loudness_std': np.float32(8.275121), 'silence_start_sec': np.float64(1.49), 'silence_end_sec': np.float64(1.21), 'silence_middle_total_sec': np.float64(1.39), 'silence_middle_count': 10, 'silence_middle_mean_sec': np.float64(0.14), 'is_silent': False}
#
# [25/454] {'id': 'TR403288', 'id_artist': 'ART25707984', 'num_samples': 7298574, 'sr': 22050, 'duration_ms': 331001.08843537414, 'bpm': np.float64(103.359375), 'centroid_mean': np.float64(2405.1452822158635), 'centroid_std': np.float64(733.6113371243551), 'rolloff_mean': np.float64(5324.742280594026), 'rolloff_std': np.float64(1685.5672725099548), 'flux_mean': np.float32(1.5029901), 'flux_std': np.float32(1.4735144), 'rms_mean': np.float32(0.27662387), 'rms_std': np.float32(0.10260082), 'zcr_mean': np.float64(0.0882976630453844), 'zcr_std': np.float64(0.05491342422865452), 'flatness_mean': np.float32(0.024051024), 'flatness_std': np.float32(0.031222543), 'spectral_complexity_mean': np.float64(2543.106864061774), 'spectral_complexity_std': np.float64(537.0471725543117), 'pitch_mean': np.float64(125.23919323273975), 'pitch_std': np.float64(112.43934836446039), 'loudness_mean': np.float32(-6.868307), 'loudness_std': np.float32(6.9288173), 'silence_start_sec': np.float64(0.12), 'silence_end_sec': np.float64(3.37), 'silence_middle_total_sec': np.float64(15.63), 'silence_middle_count': 49, 'silence_middle_mean_sec': np.float64(0.32), 'is_silent': False}
#
# [26/454] {'id': 'TR403785', 'id_artist': 'ART07024718', 'num_samples': 1056257, 'sr': 22050, 'duration_ms': 47902.811791383225, 'bpm': np.float64(95.703125), 'centroid_mean': np.float64(2526.1021938828953), 'centroid_std': np.float64(1116.2693859983463), 'rolloff_mean': np.float64(5613.5464335596835), 'rolloff_std': np.float64(2144.190880760143), 'flux_mean': np.float32(2.082979), 'flux_std': np.float32(2.2136993), 'rms_mean': np.float32(0.24720427), 'rms_std': np.float32(0.09736896), 'zcr_mean': np.float64(0.08731836126756298), 'zcr_std': np.float64(0.07511374821870659), 'flatness_mean': np.float32(0.030166127), 'flatness_std': np.float32(0.04716925), 'spectral_complexity_mean': np.float64(2748.779172734357), 'spectral_complexity_std': np.float64(506.0759448770388), 'pitch_mean': np.float64(93.15390374657386), 'pitch_std': np.float64(51.71709505951371), 'loudness_mean': np.float32(-8.325793), 'loudness_std': np.float32(6.445284), 'silence_start_sec': np.float64(0.0), 'silence_end_sec': np.float64(0.3), 'silence_middle_total_sec': np.float64(1.44), 'silence_middle_count': 6, 'silence_middle_mean_sec': np.float64(0.24), 'is_silent': False}
#
# [27/454] {'id': 'TR480259', 'id_artist': 'ART07024718', 'num_samples': 3581953, 'sr': 22050, 'duration_ms': 162446.84807256234, 'bpm': np.float64(129.19921875), 'centroid_mean': np.float64(2742.506649485091), 'centroid_std': np.float64(1035.8601309005862), 'rolloff_mean': np.float64(5995.332147789901), 'rolloff_std': np.float64(2013.847010194742), 'flux_mean': np.float32(1.5895464), 'flux_std': np.float32(1.9179398), 'rms_mean': np.float32(0.33961743), 'rms_std': np.float32(0.16795735), 'zcr_mean': np.float64(0.12358665711644276), 'zcr_std': np.float64(0.090385156834673), 'flatness_mean': np.float32(0.05344524), 'flatness_std': np.float32(0.06605157), 'spectral_complexity_mean': np.float64(2734.3572502922825), 'spectral_complexity_std': np.float64(573.2141222332203), 'pitch_mean': np.float64(113.28023474842868), 'pitch_std': np.float64(84.07506903772693), 'loudness_mean': np.float32(-8.660101), 'loudness_std': np.float32(7.872125), 'silence_start_sec': np.float64(0.0), 'silence_end_sec': np.float64(1.3), 'silence_middle_total_sec': np.float64(5.22), 'silence_middle_count': 33, 'silence_middle_mean_sec': np.float64(0.16), 'is_silent': False}
#
# [28/454] {'id': 'TR609770', 'id_artist': 'ART25707984', 'num_samples': 5765928, 'sr': 22050, 'duration_ms': 261493.33333333334, 'bpm': np.float64(86.1328125), 'centroid_mean': np.float64(2316.5161375072685), 'centroid_std': np.float64(975.7279149401385), 'rolloff_mean': np.float64(5157.662945982618), 'rolloff_std': np.float64(2054.1146198366628), 'flux_mean': np.float32(1.5734844), 'flux_std': np.float32(2.110109), 'rms_mean': np.float32(0.23500203), 'rms_std': np.float32(0.12120602), 'zcr_mean': np.float64(0.07978247681639584), 'zcr_std': np.float64(0.056579166699661794), 'flatness_mean': np.float32(0.02128618), 'flatness_std': np.float32(0.051247634), 'spectral_complexity_mean': np.float64(2499.6126375378253), 'spectral_complexity_std': np.float64(625.274542290864), 'pitch_mean': np.float64(92.15952149314961), 'pitch_std': np.float64(48.53022293208353), 'loudness_mean': np.float32(-10.07002), 'loudness_std': np.float32(7.1732507), 'silence_start_sec': np.float64(0.02), 'silence_end_sec': np.float64(3.96), 'silence_middle_total_sec': np.float64(8.73), 'silence_middle_count': 25, 'silence_middle_mean_sec': np.float64(0.35), 'is_silent': False}
#
# [29/454] {'id': 'TR224256', 'id_artist': 'ART25707984', 'num_samples': 5834753, 'sr': 22050, 'duration_ms': 264614.6485260771, 'bpm': np.float64(92.28515625), 'centroid_mean': np.float64(2281.1324919782246), 'centroid_std': np.float64(1383.3421940784867), 'rolloff_mean': np.float64(4900.590114688898), 'rolloff_std': np.float64(2776.176050672419), 'flux_mean': np.float32(1.7804005), 'flux_std': np.float32(2.440853), 'rms_mean': np.float32(0.1962538), 'rms_std': np.float32(0.15358482), 'zcr_mean': np.float64(0.09259109784921471), 'zcr_std': np.float64(0.09426364349902287), 'flatness_mean': np.float32(0.023001311), 'flatness_std': np.float32(0.046680905), 'spectral_complexity_mean': np.float64(2405.117628276076), 'spectral_complexity_std': np.float64(887.9818535970752), 'pitch_mean': np.float64(139.41887719374276), 'pitch_std': np.float64(91.65703970405373), 'loudness_mean': np.float32(-13.329718), 'loudness_std': np.float32(11.527914), 'silence_start_sec': np.float64(0.19), 'silence_end_sec': np.float64(7.15), 'silence_middle_total_sec': np.float64(35.25), 'silence_middle_count': 177, 'silence_middle_mean_sec': np.float64(0.2), 'is_silent': False}
#
# [30/454] {'id': 'TR961564', 'id_artist': 'ART25707984', 'num_samples': 3996120, 'sr': 22050, 'duration_ms': 181229.9319727891, 'bpm': np.float64(172.265625), 'centroid_mean': np.float64(2677.8047226055382), 'centroid_std': np.float64(1153.3217712420792), 'rolloff_mean': np.float64(5949.141216192545), 'rolloff_std': np.float64(2125.1420807085856), 'flux_mean': np.float32(2.0763347), 'flux_std': np.float32(2.8206596), 'rms_mean': np.float32(0.34897125), 'rms_std': np.float32(0.14057301), 'zcr_mean': np.float64(0.08922747087203715), 'zcr_std': np.float64(0.07220868129502885), 'flatness_mean': np.float32(0.028452842), 'flatness_std': np.float32(0.040520236), 'spectral_complexity_mean': np.float64(2776.710390535224), 'spectral_complexity_std': np.float64(541.7673338243745), 'pitch_mean': np.float64(101.18535099634845), 'pitch_std': np.float64(67.45245903792818), 'loudness_mean': np.float32(-7.4155087), 'loudness_std': np.float32(8.225639), 'silence_start_sec': np.float64(0.0), 'silence_end_sec': np.float64(2.55), 'silence_middle_total_sec': np.float64(2.6), 'silence_middle_count': 38, 'silence_middle_mean_sec': np.float64(0.07), 'is_silent': False}
#
# [31/454] {'id': 'TR250056', 'id_artist': 'ART25707984', 'num_samples': 4615212, 'sr': 22050, 'duration_ms': 209306.6666666667, 'bpm': np.float64(103.359375), 'centroid_mean': np.float64(2981.5035391018705), 'centroid_std': np.float64(771.8016083918747), 'rolloff_mean': np.float64(6839.101765612001), 'rolloff_std': np.float64(1259.8285157773646), 'flux_mean': np.float32(1.5639118), 'flux_std': np.float32(1.4598773), 'rms_mean': np.float32(0.20497271), 'rms_std': np.float32(0.07537842), 'zcr_mean': np.float64(0.12047498960066556), 'zcr_std': np.float64(0.0566536845915402), 'flatness_mean': np.float32(0.037759427), 'flatness_std': np.float32(0.030824335), 'spectral_complexity_mean': np.float64(3020.8574214892888), 'spectral_complexity_std': np.float64(333.24534465508077), 'pitch_mean': np.float64(128.04347283457346), 'pitch_std': np.float64(95.50660582479848), 'loudness_mean': np.float32(-6.5798216), 'loudness_std': np.float32(3.2822576), 'silence_start_sec': np.float64(0.21), 'silence_end_sec': np.float64(0.03), 'silence_middle_total_sec': np.float64(0.28), 'silence_middle_count': 2, 'silence_middle_mean_sec': np.float64(0.14), 'is_silent': False}
#
# [32/454] {'id': 'TR803061', 'id_artist': 'ART25707984', 'num_samples': 5919102, 'sr': 22050, 'duration_ms': 268440.0, 'bpm': np.float64(161.4990234375), 'centroid_mean': np.float64(3177.4025401903673), 'centroid_std': np.float64(717.5709102431794), 'rolloff_mean': np.float64(6932.264675552504), 'rolloff_std': np.float64(1195.3106074212164), 'flux_mean': np.float32(1.4412309), 'flux_std': np.float32(1.3568419), 'rms_mean': np.float32(0.23818481), 'rms_std': np.float32(0.09720437), 'zcr_mean': np.float64(0.14692471928790762), 'zcr_std': np.float64(0.06257094286394128), 'flatness_mean': np.float32(0.052750032), 'flatness_std': np.float32(0.044965804), 'spectral_complexity_mean': np.float64(2988.412755838906), 'spectral_complexity_std': np.float64(307.3154360341692), 'pitch_mean': np.float64(112.32721532344132), 'pitch_std': np.float64(85.52467751986812), 'loudness_mean': np.float32(-7.683416), 'loudness_std': np.float32(7.9247003), 'silence_start_sec': np.float64(0.3), 'silence_end_sec': np.float64(3.5), 'silence_middle_total_sec': np.float64(0.49), 'silence_middle_count': 8, 'silence_middle_mean_sec': np.float64(0.06), 'is_silent': False}
#
# [33/454] {'id': 'TR660156', 'id_artist': 'ART07024718', 'num_samples': 3947009, 'sr': 22050, 'duration_ms': 179002.67573696148, 'bpm': np.float64(89.10290948275862), 'centroid_mean': np.float64(2370.211056798768), 'centroid_std': np.float64(1028.845670482607), 'rolloff_mean': np.float64(5304.155786417801), 'rolloff_std': np.float64(2274.9625891195956), 'flux_mean': np.float32(1.6077996), 'flux_std': np.float32(1.6271269), 'rms_mean': np.float32(0.21919477), 'rms_std': np.float32(0.12474681), 'zcr_mean': np.float64(0.07545680579199092), 'zcr_std': np.float64(0.06383833573362907), 'flatness_mean': np.float32(0.017244056), 'flatness_std': np.float32(0.045514286), 'spectral_complexity_mean': np.float64(2686.33273539886), 'spectral_complexity_std': np.float64(581.941396194501), 'pitch_mean': np.float64(113.3331825682316), 'pitch_std': np.float64(108.50372113625282), 'loudness_mean': np.float32(-9.389591), 'loudness_std': np.float32(9.342949), 'silence_start_sec': np.float64(0.07), 'silence_end_sec': np.float64(8.29), 'silence_middle_total_sec': np.float64(6.36), 'silence_middle_count': 58, 'silence_middle_mean_sec': np.float64(0.11), 'is_silent': False}
#
# [34/454] {'id': 'TR174989', 'id_artist': 'ART25707984', 'num_samples': 3684097, 'sr': 22050, 'duration_ms': 167079.2290249433, 'bpm': np.float64(172.265625), 'centroid_mean': np.float64(2604.1354434264845), 'centroid_std': np.float64(1109.0493717807656), 'rolloff_mean': np.float64(5752.017983759423), 'rolloff_std': np.float64(2259.970121451051), 'flux_mean': np.float32(2.0795846), 'flux_std': np.float32(2.732911), 'rms_mean': np.float32(0.11203138), 'rms_std': np.float32(0.048712984), 'zcr_mean': np.float64(0.10064368171119371), 'zcr_std': np.float64(0.08532739279320443), 'flatness_mean': np.float32(0.039456535), 'flatness_std': np.float32(0.07909867), 'spectral_complexity_mean': np.float64(2800.4762094739935), 'spectral_complexity_std': np.float64(529.4438075712875), 'pitch_mean': np.float64(107.05901880126883), 'pitch_std': np.float64(74.97109511000119), 'loudness_mean': np.float32(-7.5866814), 'loudness_std': np.float32(8.447483), 'silence_start_sec': np.float64(0.53), 'silence_end_sec': np.float64(1.06), 'silence_middle_total_sec': np.float64(5.83), 'silence_middle_count': 44, 'silence_middle_mean_sec': np.float64(0.13), 'is_silent': False}
#
# [35/454] {'id': 'TR357474', 'id_artist': 'ART07024718', 'num_samples': 3374593, 'sr': 22050, 'duration_ms': 153042.7664399093, 'bpm': np.float64(92.28515625), 'centroid_mean': np.float64(2713.278689796771), 'centroid_std': np.float64(847.7207681905367), 'rolloff_mean': np.float64(5992.773400464104), 'rolloff_std': np.float64(1723.5293529641337), 'flux_mean': np.float32(1.6182978), 'flux_std': np.float32(1.6434655), 'rms_mean': np.float32(0.29442284), 'rms_std': np.float32(0.124163456), 'zcr_mean': np.float64(0.10882820203466323), 'zcr_std': np.float64(0.06212782208933266), 'flatness_mean': np.float32(0.033522632), 'flatness_std': np.float32(0.07830471), 'spectral_complexity_mean': np.float64(2767.9556943234247), 'spectral_complexity_std': np.float64(443.5409338089706), 'pitch_mean': np.float64(156.92107322194983), 'pitch_std': np.float64(116.98668629379318), 'loudness_mean': np.float32(-7.938689), 'loudness_std': np.float32(11.29761), 'silence_start_sec': np.float64(0.49), 'silence_end_sec': np.float64(4.09), 'silence_middle_total_sec': np.float64(1.58), 'silence_middle_count': 10, 'silence_middle_mean_sec': np.float64(0.16), 'is_silent': False}
#
# [36/454] {'id': 'TR253898', 'id_artist': 'ART07024718', 'num_samples': 2900957, 'sr': 22050, 'duration_ms': 131562.67573696145, 'bpm': np.float64(123.046875), 'centroid_mean': np.float64(2329.759401153814), 'centroid_std': np.float64(934.6396831096023), 'rolloff_mean': np.float64(5479.582626391249), 'rolloff_std': np.float64(2246.181053589209), 'flux_mean': np.float32(1.4708872), 'flux_std': np.float32(1.5442928), 'rms_mean': np.float32(0.2931962), 'rms_std': np.float32(0.105000466), 'zcr_mean': np.float64(0.07970945800608895), 'zcr_std': np.float64(0.05220532638879811), 'flatness_mean': np.float32(0.021041688), 'flatness_std': np.float32(0.03836212), 'spectral_complexity_mean': np.float64(2601.218942836645), 'spectral_complexity_std': np.float64(731.7065344578218), 'pitch_mean': np.float64(99.5288468684461), 'pitch_std': np.float64(72.67369199126367), 'loudness_mean': np.float32(-6.962654), 'loudness_std': np.float32(8.325912), 'silence_start_sec': np.float64(0.21), 'silence_end_sec': np.float64(3.11), 'silence_middle_total_sec': np.float64(1.58), 'silence_middle_count': 12, 'silence_middle_mean_sec': np.float64(0.13), 'is_silent': False}
#
# [37/454] {'id': 'TR802307', 'id_artist': 'ART07024718', 'num_samples': 3787896, 'sr': 22050, 'duration_ms': 171786.66666666666, 'bpm': np.float64(103.359375), 'centroid_mean': np.float64(2331.302222985113), 'centroid_std': np.float64(987.5245626816675), 'rolloff_mean': np.float64(5035.648249948262), 'rolloff_std': np.float64(1986.8440357526217), 'flux_mean': np.float32(1.6803464), 'flux_std': np.float32(1.6642491), 'rms_mean': np.float32(0.35486016), 'rms_std': np.float32(0.10960848), 'zcr_mean': np.float64(0.08566633529446546), 'zcr_std': np.float64(0.06896787223101906), 'flatness_mean': np.float32(0.03225799), 'flatness_std': np.float32(0.08061202), 'spectral_complexity_mean': np.float64(2479.1752031972383), 'spectral_complexity_std': np.float64(598.8012925473134), 'pitch_mean': np.float64(104.52053150468184), 'pitch_std': np.float64(63.96018485542247), 'loudness_mean': np.float32(-6.8676944), 'loudness_std': np.float32(10.473437), 'silence_start_sec': np.float64(0.28), 'silence_end_sec': np.float64(6.76), 'silence_middle_total_sec': np.float64(0.02), 'silence_middle_count': 1, 'silence_middle_mean_sec': np.float64(0.02), 'is_silent': False}
#
# [38/454] {'id': 'TR198241', 'id_artist': 'ART25707984', 'num_samples': 6284838, 'sr': 22050, 'duration_ms': 285026.6666666666, 'bpm': np.float64(112.34714673913044), 'centroid_mean': np.float64(2293.8526838967923), 'centroid_std': np.float64(997.5349661925952), 'rolloff_mean': np.float64(5008.125587083028), 'rolloff_std': np.float64(2223.410756007766), 'flux_mean': np.float32(1.4712039), 'flux_std': np.float32(1.6057006), 'rms_mean': np.float32(0.24283946), 'rms_std': np.float32(0.11453942), 'zcr_mean': np.float64(0.084489680066797), 'zcr_std': np.float64(0.05630979375834747), 'flatness_mean': np.float32(0.019099476), 'flatness_std': np.float32(0.061883498), 'spectral_complexity_mean': np.float64(2452.780439115792), 'spectral_complexity_std': np.float64(700.703881851544), 'pitch_mean': np.float64(119.12644808170079), 'pitch_std': np.float64(91.78314305094025), 'loudness_mean': np.float32(-9.883041), 'loudness_std': np.float32(8.974439), 'silence_start_sec': np.float64(0.19), 'silence_end_sec': np.float64(5.55), 'silence_middle_total_sec': np.float64(7.66), 'silence_middle_count': 95, 'silence_middle_mean_sec': np.float64(0.08), 'is_silent': False}
#
# [39/454] {'id': 'TR958743', 'id_artist': 'ART25707984', 'num_samples': 5376257, 'sr': 22050, 'duration_ms': 243821.179138322, 'bpm': np.float64(151.99908088235293), 'centroid_mean': np.float64(2981.3772990472416), 'centroid_std': np.float64(800.6975106308272), 'rolloff_mean': np.float64(6397.569809199719), 'rolloff_std': np.float64(1338.0219000194697), 'flux_mean': np.float32(1.5788578), 'flux_std': np.float32(1.4604791), 'rms_mean': np.float32(0.23451497), 'rms_std': np.float32(0.07381092), 'zcr_mean': np.float64(0.12256868393486335), 'zcr_std': np.float64(0.0732452195324854), 'flatness_mean': np.float32(0.047408972), 'flatness_std': np.float32(0.072340295), 'spectral_complexity_mean': np.float64(2836.817277471722), 'spectral_complexity_std': np.float64(367.4179125918938), 'pitch_mean': np.float64(102.3271414687782), 'pitch_std': np.float64(78.10383448403138), 'loudness_mean': np.float32(-4.901603), 'loudness_std': np.float32(6.4598703), 'silence_start_sec': np.float64(0.12), 'silence_end_sec': np.float64(1.4), 'silence_middle_total_sec': np.float64(1.58), 'silence_middle_count': 19, 'silence_middle_mean_sec': np.float64(0.08), 'is_silent': False}
#
# [40/454] {'id': 'TR414333', 'id_artist': 'ART25707984', 'num_samples': 5248769, 'sr': 22050, 'duration_ms': 238039.41043083902, 'bpm': np.float64(112.34714673913044), 'centroid_mean': np.float64(3077.8502930491395), 'centroid_std': np.float64(761.8198727988313), 'rolloff_mean': np.float64(6539.832486001207), 'rolloff_std': np.float64(1040.806642057318), 'flux_mean': np.float32(1.6322923), 'flux_std': np.float32(1.6146002), 'rms_mean': np.float32(0.23301694), 'rms_std': np.float32(0.09329899), 'zcr_mean': np.float64(0.14278363939658115), 'zcr_std': np.float64(0.07575006338220995), 'flatness_mean': np.float32(0.04535148), 'flatness_std': np.float32(0.04647546), 'spectral_complexity_mean': np.float64(2873.7200189960054), 'spectral_complexity_std': np.float64(272.84671084696464), 'pitch_mean': np.float64(130.35740340694812), 'pitch_std': np.float64(83.83460505568331), 'loudness_mean': np.float32(-7.157256), 'loudness_std': np.float32(5.980604), 'silence_start_sec': np.float64(0.79), 'silence_end_sec': np.float64(3.1), 'silence_middle_total_sec': np.float64(1.83), 'silence_middle_count': 31, 'silence_middle_mean_sec': np.float64(0.06), 'is_silent': False}
#
# ...
#
# [441/454] {'id': 'TR605119', 'id_artist': 'ART25707984', 'num_samples': 1965057, 'sr': 22050, 'duration_ms': 89118.23129251701, 'bpm': np.float64(129.19921875), 'centroid_mean': np.float64(2328.021015981274), 'centroid_std': np.float64(893.7482792681666), 'rolloff_mean': np.float64(5176.545011416547), 'rolloff_std': np.float64(1764.0125518506607), 'flux_mean': np.float32(1.5122614), 'flux_std': np.float32(1.2871617), 'rms_mean': np.float32(0.28391895), 'rms_std': np.float32(0.08037788), 'zcr_mean': np.float64(0.07152627128646782), 'zcr_std': np.float64(0.060429411625314386), 'flatness_mean': np.float32(0.01822963), 'flatness_std': np.float32(0.032133717), 'spectral_complexity_mean': np.float64(2507.6323578688866), 'spectral_complexity_std': np.float64(511.6416417601687), 'pitch_mean': np.float64(141.34535296194687), 'pitch_std': np.float64(110.29710582580933), 'loudness_mean': np.float32(-6.012687), 'loudness_std': np.float32(4.034077), 'silence_start_sec': np.float64(0.14), 'silence_end_sec': np.float64(0.0), 'silence_middle_total_sec': np.float64(0.09), 'silence_middle_count': 1, 'silence_middle_mean_sec': np.float64(0.09), 'is_silent': False}
#
# [442/454] {'id': 'TR843290', 'id_artist': 'ART07024718', 'num_samples': 4423818, 'sr': 22050, 'duration_ms': 200626.66666666666, 'bpm': np.float64(161.4990234375), 'centroid_mean': np.float64(2238.341801838497), 'centroid_std': np.float64(924.8508638036453), 'rolloff_mean': np.float64(5132.605055341179), 'rolloff_std': np.float64(1963.6907916965722), 'flux_mean': np.float32(1.787186), 'flux_std': np.float32(2.2953734), 'rms_mean': np.float32(0.26681182), 'rms_std': np.float32(0.1054112), 'zcr_mean': np.float64(0.07979140597876404), 'zcr_std': np.float64(0.05872775462927552), 'flatness_mean': np.float32(0.01766354), 'flatness_std': np.float32(0.0336339), 'spectral_complexity_mean': np.float64(2578.967108429436), 'spectral_complexity_std': np.float64(512.368153001546), 'pitch_mean': np.float64(94.71814079522088), 'pitch_std': np.float64(57.02422997789699), 'loudness_mean': np.float32(-7.75301), 'loudness_std': np.float32(7.989972), 'silence_start_sec': np.float64(0.05), 'silence_end_sec': np.float64(1.93), 'silence_middle_total_sec': np.float64(4.62), 'silence_middle_count': 50, 'silence_middle_mean_sec': np.float64(0.09), 'is_silent': False}
#
# [443/454] {'id': 'TR456894', 'id_artist': 'ART25707984', 'num_samples': 5859329, 'sr': 22050, 'duration_ms': 265729.20634920633, 'bpm': np.float64(103.359375), 'centroid_mean': np.float64(2677.593086455967), 'centroid_std': np.float64(901.1860834437207), 'rolloff_mean': np.float64(5905.304571029244), 'rolloff_std': np.float64(1705.1716900299512), 'flux_mean': np.float32(1.5411528), 'flux_std': np.float32(1.5805801), 'rms_mean': np.float32(0.24622326), 'rms_std': np.float32(0.106846996), 'zcr_mean': np.float64(0.10691153683377021), 'zcr_std': np.float64(0.06461946838477345), 'flatness_mean': np.float32(0.037700694), 'flatness_std': np.float32(0.07900283), 'spectral_complexity_mean': np.float64(2730.2677875420895), 'spectral_complexity_std': np.float64(498.5267391290588), 'pitch_mean': np.float64(91.75976789133034), 'pitch_std': np.float64(63.102459864045926), 'loudness_mean': np.float32(-9.846376), 'loudness_std': np.float32(9.84142), 'silence_start_sec': np.float64(0.84), 'silence_end_sec': np.float64(6.32), 'silence_middle_total_sec': np.float64(3.67), 'silence_middle_count': 28, 'silence_middle_mean_sec': np.float64(0.13), 'is_silent': False}
#
# [444/454] {'id': 'TR977799', 'id_artist': 'ART25707984', 'num_samples': 5455105, 'sr': 22050, 'duration_ms': 247397.05215419503, 'bpm': np.float64(95.703125), 'centroid_mean': np.float64(2765.781756847163), 'centroid_std': np.float64(848.6449197427835), 'rolloff_mean': np.float64(5999.904204305491), 'rolloff_std': np.float64(1836.46993144129), 'flux_mean': np.float32(1.597514), 'flux_std': np.float32(1.4454972), 'rms_mean': np.float32(0.2715208), 'rms_std': np.float32(0.10751404), 'zcr_mean': np.float64(0.12207127485628813), 'zcr_std': np.float64(0.05488050403551168), 'flatness_mean': np.float32(0.035408437), 'flatness_std': np.float32(0.042484775), 'spectral_complexity_mean': np.float64(2694.476549142869), 'spectral_complexity_std': np.float64(652.7826282426796), 'pitch_mean': np.float64(156.25656492620905), 'pitch_std': np.float64(122.94375138946204), 'loudness_mean': np.float32(-6.649016), 'loudness_std': np.float32(6.7030983), 'silence_start_sec': np.float64(0.35), 'silence_end_sec': np.float64(1.52), 'silence_middle_total_sec': np.float64(8.78), 'silence_middle_count': 31, 'silence_middle_mean_sec': np.float64(0.28), 'is_silent': False}
#
# [445/454] {'id': 'TR669412', 'id_artist': 'ART07024718', 'num_samples': 1765376, 'sr': 22050, 'duration_ms': 80062.40362811791, 'bpm': np.float64(89.10290948275862), 'centroid_mean': np.float64(2431.5826838215394), 'centroid_std': np.float64(1057.4695182946525), 'rolloff_mean': np.float64(5106.615665885945), 'rolloff_std': np.float64(2092.4075750924953), 'flux_mean': np.float32(1.6927298), 'flux_std': np.float32(1.561801), 'rms_mean': np.float32(0.27315298), 'rms_std': np.float32(0.0920528), 'zcr_mean': np.float64(0.1161681828066106), 'zcr_std': np.float64(0.08890993640603585), 'flatness_mean': np.float32(0.027792001), 'flatness_std': np.float32(0.07369987), 'spectral_complexity_mean': np.float64(2512.3288323375605), 'spectral_complexity_std': np.float64(519.3251828694974), 'pitch_mean': np.float64(145.04136655008975), 'pitch_std': np.float64(97.71351083780323), 'loudness_mean': np.float32(-7.7449317), 'loudness_std': np.float32(10.086905), 'silence_start_sec': np.float64(1.25), 'silence_end_sec': np.float64(0.14), 'silence_middle_total_sec': 0, 'silence_middle_count': 0, 'silence_middle_mean_sec': 0, 'is_silent': False}
#
# [446/454] {'id': 'TR762452', 'id_artist': 'ART25707984', 'num_samples': 5725696, 'sr': 22050, 'duration_ms': 259668.7528344671, 'bpm': np.float64(151.99908088235293), 'centroid_mean': np.float64(2049.5514808210196), 'centroid_std': np.float64(1020.4846531306115), 'rolloff_mean': np.float64(4580.053003663157), 'rolloff_std': np.float64(2223.0965459236236), 'flux_mean': np.float32(1.7566131), 'flux_std': np.float32(2.0361922), 'rms_mean': np.float32(0.2584592), 'rms_std': np.float32(0.0973168), 'zcr_mean': np.float64(0.07489271259444295), 'zcr_std': np.float64(0.06085933651162375), 'flatness_mean': np.float32(0.015311649), 'flatness_std': np.float32(0.039286066), 'spectral_complexity_mean': np.float64(2471.888454591047), 'spectral_complexity_std': np.float64(642.818525006303), 'pitch_mean': np.float64(115.34782193205963), 'pitch_std': np.float64(70.99941662953353), 'loudness_mean': np.float32(-7.8294168), 'loudness_std': np.float32(5.91913), 'silence_start_sec': np.float64(0.21), 'silence_end_sec': np.float64(1.16), 'silence_middle_total_sec': np.float64(2.25), 'silence_middle_count': 19, 'silence_middle_mean_sec': np.float64(0.12), 'is_silent': False}
#
# [447/454] {'id': 'TR943991', 'id_artist': 'ART07024718', 'num_samples': 4212225, 'sr': 22050, 'duration_ms': 191030.61224489796, 'bpm': np.float64(123.046875), 'centroid_mean': np.float64(2400.2300225850945), 'centroid_std': np.float64(822.5047088378179), 'rolloff_mean': np.float64(5555.257592690356), 'rolloff_std': np.float64(1840.2305732577654), 'flux_mean': np.float32(1.4623904), 'flux_std': np.float32(1.0858716), 'rms_mean': np.float32(0.31194708), 'rms_std': np.float32(0.09104195), 'zcr_mean': np.float64(0.08636756492692635), 'zcr_std': np.float64(0.05433087866019667), 'flatness_mean': np.float32(0.019713374), 'flatness_std': np.float32(0.06788119), 'spectral_complexity_mean': np.float64(2709.2846081086977), 'spectral_complexity_std': np.float64(538.4030585390063), 'pitch_mean': np.float64(90.88907163558731), 'pitch_std': np.float64(75.66898434350594), 'loudness_mean': np.float32(-5.570857), 'loudness_std': np.float32(6.4381022), 'silence_start_sec': np.float64(0.09), 'silence_end_sec': np.float64(1.09), 'silence_middle_total_sec': np.float64(0.63), 'silence_middle_count': 4, 'silence_middle_mean_sec': np.float64(0.16), 'is_silent': False}
#
# [448/454] {'id': 'TR483704', 'id_artist': 'ART25707984', 'num_samples': 3848449, 'sr': 22050, 'duration_ms': 174532.83446712018, 'bpm': np.float64(83.35433467741936), 'centroid_mean': np.float64(2746.889234071892), 'centroid_std': np.float64(674.5776034340164), 'rolloff_mean': np.float64(5944.191021834883), 'rolloff_std': np.float64(1288.0098567308573), 'flux_mean': np.float32(1.4779947), 'flux_std': np.float32(1.3519715), 'rms_mean': np.float32(0.08748154), 'rms_std': np.float32(0.03046647), 'zcr_mean': np.float64(0.12783251193128908), 'zcr_std': np.float64(0.051732547362955406), 'flatness_mean': np.float32(0.03911539), 'flatness_std': np.float32(0.061495796), 'spectral_complexity_mean': np.float64(2655.3574720553256), 'spectral_complexity_std': np.float64(369.1718226474026), 'pitch_mean': np.float64(102.29294368635797), 'pitch_std': np.float64(71.06897616810207), 'loudness_mean': np.float32(-7.261582), 'loudness_std': np.float32(5.0697613), 'silence_start_sec': np.float64(0.51), 'silence_end_sec': np.float64(0.01), 'silence_middle_total_sec': np.float64(0.19), 'silence_middle_count': 2, 'silence_middle_mean_sec': np.float64(0.09), 'is_silent': False}
#
# [449/454] {'id': 'TR986135', 'id_artist': 'ART07024718', 'num_samples': 3484673, 'sr': 22050, 'duration_ms': 158035.05668934243, 'bpm': np.float64(123.046875), 'centroid_mean': np.float64(2825.5375467434733), 'centroid_std': np.float64(984.8202619538267), 'rolloff_mean': np.float64(6804.201155520052), 'rolloff_std': np.float64(1520.4815945464713), 'flux_mean': np.float32(1.5008272), 'flux_std': np.float32(1.2754565), 'rms_mean': np.float32(0.31965017), 'rms_std': np.float32(0.07281092), 'zcr_mean': np.float64(0.09529102337208022), 'zcr_std': np.float64(0.06674029495810545), 'flatness_mean': np.float32(0.026009033), 'flatness_std': np.float32(0.030115727), 'spectral_complexity_mean': np.float64(3105.8085286195465), 'spectral_complexity_std': np.float64(384.1963573090536), 'pitch_mean': np.float64(88.5123348739343), 'pitch_std': np.float64(58.81877928323264), 'loudness_mean': np.float32(-4.180458), 'loudness_std': np.float32(4.1673174), 'silence_start_sec': np.float64(0.0), 'silence_end_sec': np.float64(0.28), 'silence_middle_total_sec': np.float64(0.42), 'silence_middle_count': 4, 'silence_middle_mean_sec': np.float64(0.1), 'is_silent': False}
#
# [450/454] {'id': 'TR878128', 'id_artist': 'ART25707984', 'num_samples': 5094401, 'sr': 22050, 'duration_ms': 231038.5941043084, 'bpm': np.float64(89.10290948275862), 'centroid_mean': np.float64(2702.6767749954647), 'centroid_std': np.float64(852.5231906824303), 'rolloff_mean': np.float64(5980.28292490626), 'rolloff_std': np.float64(1572.894642457533), 'flux_mean': np.float32(1.5526414), 'flux_std': np.float32(1.3926262), 'rms_mean': np.float32(0.24560612), 'rms_std': np.float32(0.10411785), 'zcr_mean': np.float64(0.11293830982752989), 'zcr_std': np.float64(0.06141234573999028), 'flatness_mean': np.float32(0.03223873), 'flatness_std': np.float32(0.03653162), 'spectral_complexity_mean': np.float64(2767.871416757288), 'spectral_complexity_std': np.float64(409.0590362831264), 'pitch_mean': np.float64(126.79535910692324), 'pitch_std': np.float64(78.04511245115418), 'loudness_mean': np.float32(-8.002803), 'loudness_std': np.float32(7.688106), 'silence_start_sec': np.float64(0.26), 'silence_end_sec': np.float64(5.11), 'silence_middle_total_sec': np.float64(0.09), 'silence_middle_count': 3, 'silence_middle_mean_sec': np.float64(0.03), 'is_silent': False}
#
# [451/454] {'id': 'TR478130', 'id_artist': 'ART07024718', 'num_samples': 3169281, 'sr': 22050, 'duration_ms': 143731.56462585035, 'bpm': np.float64(129.19921875), 'centroid_mean': np.float64(2925.9933663971224), 'centroid_std': np.float64(1115.2676269970912), 'rolloff_mean': np.float64(6416.529325898987), 'rolloff_std': np.float64(2048.021621885343), 'flux_mean': np.float32(1.7270736), 'flux_std': np.float32(1.665137), 'rms_mean': np.float32(0.28002402), 'rms_std': np.float32(0.1406015), 'zcr_mean': np.float64(0.1067771954752867), 'zcr_std': np.float64(0.08021259329238911), 'flatness_mean': np.float32(0.036334656), 'flatness_std': np.float32(0.07523945), 'spectral_complexity_mean': np.float64(2865.3781747983553), 'spectral_complexity_std': np.float64(624.8579422375392), 'pitch_mean': np.float64(124.2822249158393), 'pitch_std': np.float64(94.12014410235909), 'loudness_mean': np.float32(-9.315826), 'loudness_std': np.float32(10.705067), 'silence_start_sec': np.float64(1.39), 'silence_end_sec': np.float64(3.37), 'silence_middle_total_sec': np.float64(5.69), 'silence_middle_count': 32, 'silence_middle_mean_sec': np.float64(0.18), 'is_silent': False}
#
# [452/454] {'id': 'TR675727', 'id_artist': 'ART07024718', 'num_samples': 4431639, 'sr': 22050, 'duration_ms': 200981.3605442177, 'bpm': np.float64(135.99917763157896), 'centroid_mean': np.float64(2611.1047436287386), 'centroid_std': np.float64(1071.208160313498), 'rolloff_mean': np.float64(6008.400513372228), 'rolloff_std': np.float64(2225.0627904021685), 'flux_mean': np.float32(1.4366999), 'flux_std': np.float32(1.6425272), 'rms_mean': np.float32(0.26255396), 'rms_std': np.float32(0.09749574), 'zcr_mean': np.float64(0.09775773081894062), 'zcr_std': np.float64(0.06679715656665683), 'flatness_mean': np.float32(0.03369915), 'flatness_std': np.float32(0.06261699), 'spectral_complexity_mean': np.float64(2746.629840054152), 'spectral_complexity_std': np.float64(702.0849932522997), 'pitch_mean': np.float64(92.2015415173518), 'pitch_std': np.float64(47.07461841162122), 'loudness_mean': np.float32(-6.474038), 'loudness_std': np.float32(8.1574335), 'silence_start_sec': np.float64(0.33), 'silence_end_sec': np.float64(3.57), 'silence_middle_total_sec': np.float64(1.76), 'silence_middle_count': 7, 'silence_middle_mean_sec': np.float64(0.25), 'is_silent': False}
#
# [453/454] {'id': 'TR274115', 'id_artist': 'ART25707984', 'num_samples': 4853249, 'sr': 22050, 'duration_ms': 220101.99546485263, 'bpm': np.float64(89.10290948275862), 'centroid_mean': np.float64(2486.4118907695174), 'centroid_std': np.float64(868.1196362307097), 'rolloff_mean': np.float64(5341.370092464399), 'rolloff_std': np.float64(1716.7923008476546), 'flux_mean': np.float32(1.7097898), 'flux_std': np.float32(1.764443), 'rms_mean': np.float32(0.20289016), 'rms_std': np.float32(0.094257884), 'zcr_mean': np.float64(0.12040958967892933), 'zcr_std': np.float64(0.07930420427603899), 'flatness_mean': np.float32(0.047244605), 'flatness_std': np.float32(0.11715839), 'spectral_complexity_mean': np.float64(2547.378371667903), 'spectral_complexity_std': np.float64(480.55532454834736), 'pitch_mean': np.float64(141.23597432549124), 'pitch_std': np.float64(96.30954008825438), 'loudness_mean': np.float32(-9.442939), 'loudness_std': np.float32(12.154026), 'silence_start_sec': np.float64(0.33), 'silence_end_sec': np.float64(4.71), 'silence_middle_total_sec': np.float64(10.01), 'silence_middle_count': 13, 'silence_middle_mean_sec': np.float64(0.77), 'is_silent': False}
#
# Took: 1712.26

# %%
tracks_info_df = pd.DataFrame(tracks_info)
tracks_info_df.to_csv(dataset_output_dir+"tracks.csv", index=False)

# %%
# extract artists id and correlate it to name
unique_artists = tracks_info_df.id_artist.unique()
artists_names = list(tracks[tracks['id_artist'].isin(unique_artists)]['name_artist'].unique())

# %%
# check how many tracks are in the tracks df
track_matches = tracks_info_df['id'].isin(tracks['id']).sum()
missing_tracks_count = number_tracks - track_matches

print(f"Total mp3 tracks: {number_tracks} Matches found: {track_matches} Missing tracks: {missing_tracks_count}")

print(f"Artists names: {', '.join(artists_names)}")
# Out:
# Total mp3 tracks: 454 Matches found: 454 Missing tracks: 0
# Artists names: Fabri Fibra, Fedez
