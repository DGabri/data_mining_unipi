# %% [markdown]
# # 1. Introduction
#
# This section outlines the goals and context of the data understanding phase.

# %% [markdown]
# ## Library Imports
#
# In this section we import the necessary libraries for analysis:
# - `pandas`: for data manipulation
# - `numpy`: for numerical computations
# - `matplotlib` and `seaborn`: for data visualization
# - `ast`: for safe parsing of string lists
# - `pathlib`: for file path management

# %% [markdown]
# Import libraries and configure the environment.
#
# This cell imports commonly used packages (pandas, numpy, matplotlib, seaborn), sets warning filters, and updates sys.path so local modules in the parent directory (e.g., `utils.plotting`) can be imported.

# %%
import ast
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import sys
from pathlib import Path

# Add parent directory to path for importing local modules
current_dir = Path.cwd()
parent_dir = current_dir.parent
sys.path.append(str(parent_dir))

from utils.plotting import *

warnings.filterwarnings('ignore')
sns.set(style="whitegrid")

# %% [markdown]
# Load the datasets from CSV files into pandas DataFrames.
#
# This cell reads the original `artists` and `tracks` CSV files into `artists` and `tracks` variables for further inspection and processing.

# %% [markdown]
# # 2. Data Collection
#
# Load the datasets and perform an initial inspection of their structure, dimensions, and datatypes.

# %%
# load datasets from CSV to pandas df
# artsists is delimited using ; so use sep=';'
artists = pd.read_csv("../../original_datasets/artists.csv", sep=';')
tracks = pd.read_csv("../../original_datasets/tracks.csv", sep=',')

# %% [markdown]
# Show the shape (number of rows and columns) of the loaded datasets to quickly verify their dimensions.

# %%
## Datasets shape
artists_shape = artists.shape
tracks_shape = tracks.shape
print(f"Artists rows: {artists_shape[0]}, columns: {artists_shape[1]}")
print(f"Tracks  rows: {tracks_shape[0]}, columns: {tracks_shape[1]}")
# Out:
# Artists rows: 104, columns: 14
# Tracks  rows: 11166, columns: 45

# %% [markdown]
# Display a quick preview (head) of the `artists` DataFrame to inspect columns and sample rows.

# %%
## Let's see some row values by using df.head()
artists.head()
# Out:
#      id_author           name gender  birth_date birth_place nationality  \
# 0  ART82291002       99 posse      M         NaN         NaN         NaN
# 1  ART53496045  achille lauro      M  1990-07-11      Verona      Italia
# 2  ART18853907           alfa      M         NaN         NaN         NaN
# 3  ART64265460      anna pepe      F         NaN         NaN         NaN
# 4  ART75741740    articolo 31      M         NaN         NaN         NaN
#
#                             description active_start  active_end province  \
# 0              gruppo musicale italiano   1991-01-01         NaN      NaN
# 1  cantautore e rapper italiano (1990-)   2012-01-01         NaN   Verona
# 2                                   NaN          NaN         NaN      NaN
# 3                                   NaN          NaN         NaN      NaN
# 4      gruppo musicale hip hop italiano   1990-01-01         NaN      NaN
#
#    region country   latitude  longitude
# 0     NaN     NaN        NaN        NaN
# 1  Veneto  Italia  45.442498  10.985738
# 2     NaN     NaN        NaN        NaN
# 3     NaN     NaN        NaN        NaN
# 4     NaN     NaN        NaN        NaN

# %% [markdown]
# Display a quick preview (head) of the `tracks` DataFrame to inspect columns and sample rows.

# %%
tracks.head()
# Out:
#          id    id_artist    name_artist  \
# 0  TR934808  ART04205421  Rosa Chemical
# 1  TR760029  ART04205421  Rosa Chemical
# 2  TR916821  ART04205421  Rosa Chemical
# 3  TR480968  ART04205421  Rosa Chemical
# 4  TR585039  ART04205421  Rosa Chemical
#
#                                           full_title         title  \
# 0    ​polka 2 :-/ by Rosa Chemical (Ft. Ernia & Guè)  ​polka 2 :-/
# 1         POLKA by Rosa Chemical (Ft. Thelonious B.)         POLKA
# 2  ​britney ;-) by Rosa Chemical (Ft. MamboLosco ...  ​britney ;-)
# 3                  CEO by Rosa Chemical (Ft. Taxi B)           CEO
# 4                LONDRA by Rosa Chemical (Ft. Rkomi)        LONDRA
#
#       featured_artists primary_artist language              album  \
# 0           Ernia, Guè  Rosa Chemical       pl   FOREVER AND EVER
# 1        Thelonious B.  Rosa Chemical       en   FOREVER AND EVER
# 2  MamboLosco, RADICAL  Rosa Chemical       en   FOREVER AND EVER
# 3               Taxi B  Rosa Chemical       it  OKAY OKAY !! - EP
# 4                Rkomi  Rosa Chemical       en   FOREVER AND EVER
#
#    stats_pageviews  ...  album_type  disc_number track_number duration_ms  \
# 0         196033.0  ...       album          1.0          3.0    207761.0
# 1         164450.0  ...       album          1.0          3.0    207761.0
# 2          58313.0  ...       album          1.0          1.0    193544.0
# 3          39890.0  ...      single          1.0          2.0    169000.0
# 4          35432.0  ...       album          1.0          8.0    194779.0
#
#   explicit  popularity                                        album_image  \
# 0     True        46.0  https://i.scdn.co/image/ab67616d0000b2736d5e14...
# 1     True        46.0  https://i.scdn.co/image/ab67616d0000b2736d5e14...
# 2     True        39.0  https://i.scdn.co/image/ab67616d0000b2736d5e14...
# 3     True        47.0  https://i.scdn.co/image/ab67616d0000b27367c03d...
# 4     True        41.0  https://i.scdn.co/image/ab67616d0000b273fcdb60...
#
#     id_album                                             lyrics  \
# 0  ALB115557  Oplà, ah\nBdope, chiama due b—\n\nMi candidere...
# 1  ALB115557  Greg Willen, non dormire\n(Brr-poh)\n\nT-T-Tro...
# 2  ALB115557  Mothz\nYeah, yeah, yeah-yeah\nBdope, chiama du...
# 3  ALB730959  Designer sui vestiti penso di essere un outlet...
# 4  ALB436151  Bdope (Yeah)\n\nVuole solo me, non fare la gel...
#
#    modified_popularity
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
#
# [5 rows x 45 columns]

# %% [markdown]
# Inspect data types in the `artists` DataFrame (dtypes, non-null counts) to identify columns that need casting or cleaning.

# %%
###################
## Data types, let's convert data types before doing duplicate analysis so that values in rows are in the correct datat type for comprare

# 'DType' is the effective type used in the dataframe, we can see that many columns need casting to the expected data type
# let's start with artists
artists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_author     104 non-null    object
#  1   name          104 non-null    object
#  2   gender        104 non-null    object
#  3   birth_date    73 non-null     object
#  4   birth_place   72 non-null     object
#  5   nationality   71 non-null     object
#  6   description   86 non-null     object
#  7   active_start  50 non-null     object
#  8   active_end    0 non-null      float64
#  9   province      70 non-null     object
#  10  region        68 non-null     object
#  11  country       70 non-null     object
#  12  latitude      72 non-null     float64
#  13  longitude     72 non-null     float64
# dtypes: float64(3), object(11)
# memory usage: 11.5+ KB

# %% [markdown]
# We can see that columns with Dtype == `object` need casting to effectively manipulate this data.
# We divided the casting in steps based on target data types:
# - `columns_to_string`: these columns are strings from what we can see from the dataset by using artists.head()
# - `columns_to_datetime`: hese columns need to be converted to datetime, the native pandas date type.
#     - active_end column is float 64 and needs casting to datetime
# - **`no casting needed`**: latitude and longitude are already float64 which is the correct type.
#
# Finally let's run artists.info() and we can see that castings are successful

# %%
columns_to_string   = ["id_author", "name", "gender", "birth_place", "nationality", "description", "province", "region", "country"]
for column in columns_to_string:
    artists[column] = artists[column].astype('string')
    
columns_to_datetime = ["birth_date", "active_start", "active_end"]
for column in columns_to_datetime:
    artists[column] = pd.to_datetime(artists[column], errors='coerce')

artists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_author     104 non-null    string
#  1   name          104 non-null    string
#  2   gender        104 non-null    string
#  3   birth_date    72 non-null     datetime64[ns]
#  4   birth_place   72 non-null     string
#  5   nationality   71 non-null     string
#  6   description   86 non-null     string
#  7   active_start  50 non-null     datetime64[ns]
#  8   active_end    0 non-null      datetime64[ns]
#  9   province      70 non-null     string
#  10  region        68 non-null     string
#  11  country       70 non-null     string
#  12  latitude      72 non-null     float64
#  13  longitude     72 non-null     float64
# dtypes: datetime64[ns](3), float64(2), string(9)
# memory usage: 11.5 KB

# %% [markdown]
# Prepare to convert column types and inspect the DataFrame schema—this helps identify columns that need casting and cleaning before downstream analysis.

# %%
###################
# show datasets type information
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11166 entries, 0 to 11165
# Data columns (total 45 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    11166 non-null  object
#  1   id_artist             11166 non-null  object
#  2   name_artist           11166 non-null  object
#  3   full_title            11166 non-null  object
#  4   title                 11166 non-null  object
#  5   featured_artists      3517 non-null   object
#  6   primary_artist        11166 non-null  object
#  7   language              11061 non-null  object
#  8   album                 9652 non-null   object
#  9   stats_pageviews       4642 non-null   float64
#  10  swear_IT              11166 non-null  int64
#  11  swear_EN              11166 non-null  int64
#  12  swear_IT_words        11166 non-null  object
#  13  swear_EN_words        11166 non-null  object
#  14  year                  10766 non-null  object
#  15  month                 9969 non-null   float64
#  16  day                   9843 non-null   float64
#  17  n_sentences           11090 non-null  float64
#  18  n_tokens              11090 non-null  float64
#  19  tokens_per_sent       11090 non-null  float64
#  20  char_per_tok          11090 non-null  float64
#  21  lexical_density       11090 non-null  float64
#  22  avg_token_per_clause  11090 non-null  float64
#  23  bpm                   11102 non-null  float64
#  24  centroid              11102 non-null  float64
#  25  rolloff               11102 non-null  float64
#  26  flux                  11102 non-null  float64
#  27  rms                   11102 non-null  float64
#  28  zcr                   11102 non-null  float64
#  29  flatness              11102 non-null  float64
#  30  spectral_complexity   11102 non-null  float64
#  31  pitch                 11102 non-null  float64
#  32  loudness              11102 non-null  float64
#  33  album_name            11088 non-null  object
#  34  album_release_date    11088 non-null  object
#  35  album_type            11088 non-null  object
#  36  disc_number           11088 non-null  float64
#  37  track_number          11088 non-null  float64
#  38  duration_ms           11088 non-null  float64
#  39  explicit              11088 non-null  object
#  40  popularity            11164 non-null  object
#  41  album_image           11088 non-null  object
#  42  id_album              11088 non-null  object
#  43  lyrics                11163 non-null  object
#  44  modified_popularity   11166 non-null  bool
# dtypes: bool(1), float64(22), int64(2), object(20)
# memory usage: 3.8+ MB

# %% [markdown]
# On the same note as the cell above, let's convert data types for the tracks dataset

# %%
columns_to_string   = ["id", "id_artist", "name_artist", "full_title", "title", "featured_artists", "primary_artist", "language", "album", "album_name", "album_type", "lyrics", "album_image", "id_album"]
for column in columns_to_string:
    tracks[column] = tracks[column].astype('string')
    
# these columns are array of strings, let's leave them as objects
columns_to_array = ["swear_IT_words", "swear_EN_words"]

# to datetime
tracks['album_release_date'] = pd.to_datetime(tracks['album_release_date'], errors='coerce')
tracks['popularity'] = tracks['popularity'].apply(pd.to_numeric, errors='coerce')
tracks['popularity'] = tracks['popularity'].astype('Int64')

# from df.info we can see that this column is a boolean, so let's cast it to bool
tracks['explicit'] = tracks['explicit'].astype('bool')

# different values, like NaN or 2021.0 so cast to int
tracks['year'] = tracks['year'].apply(pd.to_numeric, errors='coerce')
tracks["year"] = tracks['year'].astype('Int64')

# %% [markdown]
# Display DataFrame info for `tracks` to inspect dtypes and non-null counts before performing conversions.

# %% [markdown]
# # 4. Data Quality Verification
#
# Assess data quality by checking for missing values, duplicates, outliers, and inconsistent records.

# %%
## Artists
# Check how many NaNs are present and plot the number of NaN per each column
# from the distribution we can see that no active end date is present, and about half active start
plot_nans_stacked(artists, 'NaN Percentage Per Column (Artists Dataset)')
# Out:
#               NaN Values %  NaN Values  Non-NaN Values %
# active_end      100.000000         104          0.000000
# active_start     51.923077          54         48.076923
# region           34.615385          36         65.384615
# province         32.692308          34         67.307692
# country          32.692308          34         67.307692
# nationality      31.730769          33         68.269231
# birth_date       30.769231          32         69.230769
# latitude         30.769231          32         69.230769
# longitude        30.769231          32         69.230769
# birth_place      30.769231          32         69.230769
# description      17.307692          18         82.692308
# gender            0.000000           0        100.000000
# id_author         0.000000           0        100.000000
# name              0.000000           0        100.000000

# %% [markdown]
# Visualize missing-value percentages for the `artists` dataset to identify columns with many NaNs and prioritize cleaning.

# %%
## Tracks
# Check how many NaNs are present and plot the number of NaN per each column
plot_nans_stacked(tracks, 'NaN Percentage Per Column (Tracks Dataset)')
# Out:
#                       NaN Values %  NaN Values  Non-NaN Values %
# featured_artists         68.502597        7649         31.497403
# stats_pageviews          58.427369        6524         41.572631
# album                    13.559018        1514         86.440982
# day                      11.848469        1323         88.151531
# month                    10.720043        1197         89.279957
# year                      3.922622         438         96.077378
# album_release_date        3.036002         339         96.963998
# language                  0.940355         105         99.059645
# album_type                0.698549          78         99.301451
# album_image               0.698549          78         99.301451
# disc_number               0.698549          78         99.301451
# album_name                0.698549          78         99.301451
# track_number              0.698549          78         99.301451
# id_album                  0.698549          78         99.301451
# duration_ms               0.698549          78         99.301451
# avg_token_per_clause      0.680638          76         99.319362
# n_sentences               0.680638          76         99.319362
# tokens_per_sent           0.680638          76         99.319362
# n_tokens                  0.680638          76         99.319362
# char_per_tok              0.680638          76         99.319362
# lexical_density           0.680638          76         99.319362
# pitch                     0.573169          64         99.426831
# flatness                  0.573169          64         99.426831
# flux                      0.573169          64         99.426831
# zcr                       0.573169          64         99.426831
# centroid                  0.573169          64         99.426831
# bpm                       0.573169          64         99.426831
# rolloff                   0.573169          64         99.426831
# rms                       0.573169          64         99.426831
# loudness                  0.573169          64         99.426831
# spectral_complexity       0.573169          64         99.426831
# popularity                0.259717          29         99.740283
# lyrics                    0.026867           3         99.973133
# swear_IT_words            0.000000           0        100.000000
# name_artist               0.000000           0        100.000000
# full_title                0.000000           0        100.000000
# title                     0.000000           0        100.000000
# id                        0.000000           0        100.000000
# swear_EN                  0.000000           0        100.000000
# swear_IT                  0.000000           0        100.000000
# primary_artist            0.000000           0        100.000000
# id_artist                 0.000000           0        100.000000
# swear_EN_words            0.000000           0        100.000000
# explicit                  0.000000           0        100.000000
# modified_popularity       0.000000           0        100.000000

# %% [markdown]
# Now let's analyze if there are duplicate tracks. From the results we can see that no dupl

# %%
# Tracks
tracks_duplicates = tracks.duplicated().sum()
print(f"Duplicates in tracks: {tracks_duplicates}")

# Check for duplicate track IDs
tracks_id_duplicates = tracks['id'].duplicated().sum()
print(f"Duplicate track ID: {tracks_id_duplicates}")

if tracks_id_duplicates > 0:
    print("\nTracks with duplicate IDs:")
    tracks[tracks['id'].duplicated(keep=False)].sort_values('id').head(3)


duplicate_tracks = tracks[tracks['id'].duplicated()]
dup_ids = tracks['id'][tracks['id'].duplicated(keep=False)].unique()

tracks[tracks["id"].isin(dup_ids)]

# tracks with same title and artist
if 'title' in tracks.columns and 'primary_artist' in tracks.columns:
    tracks_content_duplicates = tracks.duplicated(subset=['title', 'primary_artist']).sum()
    print(f"Number of songs with same title and artist: {tracks_content_duplicates}")
    
    if tracks_content_duplicates > 0:
        print("Songs with same title and artist:")
        duplicate_content = tracks[tracks.duplicated(subset=['title', 'primary_artist'], keep=False)]
        print(duplicate_content.sort_values(['title', 'primary_artist']))
        
        
# find duplicate (id, id_artist) pairs
tracks_id_pair_duplicates = tracks.duplicated(subset=['id', 'id_artist']).sum()
print(f"Duplicate (id, id_artist) count: {tracks_id_pair_duplicates}")

# let's print the duplicates
if tracks_id_pair_duplicates > 0:
    print("Tracks with duplicate (id, id_artist):")
    duplicate_pairs = tracks[tracks.duplicated(subset=['id', 'id_artist'], keep=False)]
    print(duplicate_pairs.sort_values(['id', 'id_artist']))
# Out:
# Duplicates in tracks: 0
# Duplicate track ID: 73
#
# Tracks with duplicate IDs:
# Number of songs with same title and artist: 2
# Songs with same title and artist:
#             id    id_artist name_artist  \
# 4627  TR367132  ART20729624      Madame
# 4628  TR367132  ART20729624      Madame
# 4647  TR367132  ART20729624      Madame
# 4648  TR367132  ART20729624      Madame
#
#                                     full_title     title   featured_artists  \
# 4627  BUGIE by Madame (Ft. Carl Brave & Rkomi)     BUGIE  Rkomi, Carl Brave
# 4628  BUGIE by Madame (Ft. Carl Brave & Rkomi)     BUGIE  Rkomi, Carl Brave
# 4647                        ​sentimi by Madame  ​sentimi               <NA>
# 4648                        ​sentimi by Madame  ​sentimi               <NA>
#
#      primary_artist language   album  stats_pageviews  ...  album_type  \
# 4627         Madame       it  MADAME          36960.0  ...       album
# 4628         Madame       it  MADAME          36960.0  ...      single
# 4647         Madame       it    <NA>          14015.0  ...       album
# 4648         Madame       it    <NA>          14015.0  ...      single
#
#       disc_number track_number duration_ms  explicit  popularity  \
# 4627          1.0          6.0    171602.0     False          48
# 4628          1.0          1.0    187660.0     False          42
# 4647          1.0          6.0    171602.0     False          48
# 4648          1.0          1.0    187660.0     False          42
#
#                                             album_image   id_album  \
# 4627  https://i.scdn.co/image/ab67616d0000b2733ccb55...  ALB468764
# 4628  https://i.scdn.co/image/ab67616d0000b27343c750...  ALB590629
# 4647  https://i.scdn.co/image/ab67616d0000b2733ccb55...  ALB468764
# 4648  https://i.scdn.co/image/ab67616d0000b27343c750...  ALB590629
#
#                                                  lyrics  modified_popularity
# 4627  E visto che non so dire di no\nSintomi da star...                False
# 4628  E visto che non so dire di no\nSintomi da star...                False
# 4647  Eh-eh-ah\nSiedi e sentimi\nYeah\n\nSiedi e sen...                False
# 4648  Eh-eh-ah\nSiedi e sentimi\nYeah\n\nSiedi e sen...                False
#
# [4 rows x 45 columns]
# Duplicate (id, id_artist) count: 3
# Tracks with duplicate (id, id_artist):
#             id    id_artist name_artist  \
# 4627  TR367132  ART20729624      Madame
# 4628  TR367132  ART20729624      Madame
# 4647  TR367132  ART20729624      Madame
# 4648  TR367132  ART20729624      Madame
#
#                                     full_title     title   featured_artists  \
# 4627  BUGIE by Madame (Ft. Carl Brave & Rkomi)     BUGIE  Rkomi, Carl Brave
# 4628  BUGIE by Madame (Ft. Carl Brave & Rkomi)     BUGIE  Rkomi, Carl Brave
# 4647                        ​sentimi by Madame  ​sentimi               <NA>
# 4648                        ​sentimi by Madame  ​sentimi               <NA>
#
#      primary_artist language   album  stats_pageviews  ...  album_type  \
# 4627         Madame       it  MADAME          36960.0  ...       album
# 4628         Madame       it  MADAME          36960.0  ...      single
# 4647         Madame       it    <NA>          14015.0  ...       album
# 4648         Madame       it    <NA>          14015.0  ...      single
#
#       disc_number track_number duration_ms  explicit  popularity  \
# 4627          1.0          6.0    171602.0     False          48
# 4628          1.0          1.0    187660.0     False          42
# 4647          1.0          6.0    171602.0     False          48
# 4648          1.0          1.0    187660.0     False          42
#
#                                             album_image   id_album  \
# 4627  https://i.scdn.co/image/ab67616d0000b2733ccb55...  ALB468764
# 4628  https://i.scdn.co/image/ab67616d0000b27343c750...  ALB590629
# 4647  https://i.scdn.co/image/ab67616d0000b2733ccb55...  ALB468764
# 4648  https://i.scdn.co/image/ab67616d0000b27343c750...  ALB590629
#
#                                                  lyrics  modified_popularity
# 4627  E visto che non so dire di no\nSintomi da star...                False
# 4628  E visto che non so dire di no\nSintomi da star...                False
# 4647  Eh-eh-ah\nSiedi e sentimi\nYeah\n\nSiedi e sen...                False
# 4648  Eh-eh-ah\nSiedi e sentimi\nYeah\n\nSiedi e sen...                False
#
# [4 rows x 45 columns]

# %% [markdown]
# Now let's analyze duplicates for artists

# %%
artists_duplicates = artists.duplicated().sum()
print(f"Duplicate rows in artists: {artists_duplicates}")

artists_id_duplicates = artists['id_author'].duplicated().sum()
print(f"Duplicate artist IDs: {artists_id_duplicates}")
# Out:
# Duplicate rows in artists: 0
# Duplicate artist IDs: 0

# %%
# Birth places distribution
plot_bar_chart_distribution(artists, 'birth_place', 'Birth Place', 'Occurrences', 'Artists Top 10 Birth Place')

# %%
# province distribution
plot_bar_chart_distribution(artists, 'province', 'Province', 'Occurrences', 'Artists Top 10 Provinces')

# %% [markdown]
# Analysing outliers

# %%
# birth year
artists['birth_year'] = pd.to_datetime(artists['birth_date'], errors='coerce').dt.year
plot_histogram(artists, 'birth_year', 'Birth Year', 'Number of Authors', 'Distribution of Authors by Birth Year', nbins=50)

# %%
# We can see some expected correlation between birth year and activity start
plot_scatter(artists, 'birth_year', 'active_start', 'Birth Year', 'Carrer Start Year', 'Birth Year vs Career Start')

# %% [markdown]
# Let's see the distribution of age at career

# %%
artists['active_start_year'] = pd.to_datetime(artists['active_start'], errors='coerce').dt.year
artists['age_at_start'] = artists['active_start_year'] - artists['birth_year']
print(f"Mean age at start: {artists['age_at_start'].mean():.2f}")
print(f"Median age at start: {artists['age_at_start'].median():.2f}")
print(f"Std dev: {artists['age_at_start'].std():.2f}")

plot_histogram(artists, 'age_at_start', 'Age At Carrer Start', 'Authors Count', 'Distribution of Age at Career Start', nbins=50)
# Out:
# Mean age at start: 18.23
# Median age at start: 18.00
# Std dev: 3.17

# %% [markdown]
# Calculate birth years from `birth_date` and plot their distribution to understand the age distribution of authors.

# %%
# We can see the map which resembles italy, partially
plot_scatter(artists, 'longitude', 'latitude', 'Longitude', 'Latitude', 'Geographic Distribution of Birth Places')

# %% [markdown]
# Plot geographic distribution of artists' birth places using latitude and longitude to visualize spatial patterns.

# %%
# gender distribution
plot_bar_chart_distribution(artists, 'gender', 'Gender', 'Occurrences', 'Artists Gender Distribution')

# %% [markdown]
# Plot the gender distribution for artists to see the composition across genders.

# %%
# region distribution
plot_bar_chart_distribution(artists, 'region', 'Region', 'Occurrences', 'Artists Region Distribution')

# %% [markdown]
# Plot region distribution of artists to identify geographic concentrations by region.

# %%
# countries distribution
plot_bar_chart_distribution(artists, 'country', 'Country', 'Occurrences', 'Artists Country Distribution')

# %% [markdown]
# Plot country distribution to see which countries most artists come from.

# %%
############
# Most used language
plot_bar_chart_distribution(tracks, 'language', 'Language', 'Occurrences', 'Track Language used')

# %% [markdown]
# Plot the distribution of track languages to understand language usage across the dataset.

# %%
# Year tracks distribution
# Use errors='coerce' so unparsable year values become NaN instead of raising an error
tracks['year'] = pd.to_numeric(tracks['year'], errors='coerce')

# Drop rows where year couldn't be parsed
tracks = tracks.dropna(subset=['year'])

# Convert to integer year now that NaNs are removed
tracks['year'] = tracks['year'].astype(int)

# Compute decade and plot
tracks['decade'] = (tracks['year'] // 10) * 10
plot_histogram(tracks, 'decade', 'Decade', 'Number of Tracks',
               'Distribution of Tracks by Decade', nbins=10)

plt.show()

# %% [markdown]
# Normalize and bucket release years into decades, then plot the distribution to reduce clutter on the x-axis and visualize trends by decade.

# %%
# Month tracks distribution
if 'month' in tracks.columns:
    plt.figure(figsize=(8, 5))
    sns.countplot(
        x=tracks['month'].dropna().astype(int),
        order=sorted(tracks['month'].dropna().astype(int).unique())
    )
    plt.title('Distribution of Track Releases by Month')
    plt.xlabel('Month')
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# Plot track release counts per month to check seasonal patterns in releases.

# %%
# Language distribution
if 'language' in tracks.columns:
    plt.figure(figsize=(10, 5))
    sns.countplot(
        x=tracks['language'].fillna('unknown'),
        order=tracks['language'].fillna('unknown').value_counts().index
    )
    plt.title('Language Distribution')
    plt.xlabel('Language')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# Plot language counts for tracks to see which languages are most common and how many tracks are in each language.

# %%
# --- Album release date distribution ---
if 'album_release_date' in tracks.columns:
    album_years = pd.to_datetime(tracks['album_release_date'], errors='coerce').dt.year
    plt.figure(figsize=(10, 5))
    sns.histplot(album_years.dropna(), bins=30)
    plt.title('Distribution of Album Release Years')
    plt.xlabel('Year')
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# Plot distribution of album release years (converted to year) to understand when albums were released across the dataset.

# %% [markdown]
# ## Musical Features Analysis
#
# This section analyzes the musical characteristics of the tracks:
# 1. **Acoustic Features**:
#    - Duration
#    - Loudness
#    - Tempo
#    - Time signature
# 2. **Audio Properties**:
#    - Acousticness
#    - Danceability
#    - Energy
#    - Instrumentalness
# 3. **Musical Elements**:
#    - Key distribution
#    - Mode (major/minor)
#    - Time signature patterns
#
# The visualizations help understand:
# - The distribution of each feature
# - Relationships between different musical aspects
# - Common patterns in contemporary music production
# - Technical characteristics of popular tracks

# %%
# Quick overview of musical features distributions
musical_cols = [c for c in ['bpm','loudness','centroid','rolloff','flux','rms','zcr','flatness','spectral_complexity','pitch'] if c in tracks.columns]
print('Found musical columns:', musical_cols)
if musical_cols:
    fig, axs = plt.subplots(len(musical_cols), 1, figsize=(8, 3*len(musical_cols)))
    for i,c in enumerate(musical_cols):
        ax = axs[i] if len(musical_cols)>1 else axs
        sns.histplot(tracks[c].dropna(), kde=True, ax=ax)
        ax.set_title(f'Distribution of {c}')
    plt.tight_layout()

    plt.show()
# Out:
# Found musical columns: ['bpm', 'loudness', 'centroid', 'rolloff', 'flux', 'rms', 'zcr', 'flatness', 'spectral_complexity', 'pitch']

# %% [markdown]
# Quickly visualize distributions for available musical features (bpm, loudness, centroid, etc.) to inspect their shapes and identify outliers.

# %% [markdown]
# ## Bad Words Analysis
#
# This section analyzes the distribution of bad words in both Italian and English:
# 1. **Overall Distribution**:
#    - Count of bad words per language
#    - Most common bad words
# 2. **Comparative Analysis**:
#    - Distribution between Italian and English bad words
#    - Tracks with most bad words

# %%
# Function to extract words from string representation of list
def extract_words(word_list_str):
    if pd.isna(word_list_str):
        return []
    try:
        return ast.literal_eval(word_list_str)
    except:
        return []

# Convert swear counts to numeric
tracks['swear_IT'] = pd.to_numeric(tracks['swear_IT'], errors='coerce').fillna(0)
tracks['swear_EN'] = pd.to_numeric(tracks['swear_EN'], errors='coerce').fillna(0)

# Extract Italian and English bad words
tracks['swear_IT_list'] = tracks['swear_IT_words'].apply(extract_words)
tracks['swear_EN_list'] = tracks['swear_EN_words'].apply(extract_words)

# Count occurrences of each bad word
it_words = [word for words in tracks['swear_IT_list'] for word in words]
en_words = [word for words in tracks['swear_EN_list'] for word in words]

it_word_counts = pd.Series(it_words).value_counts()
en_word_counts = pd.Series(en_words).value_counts()

# Create visualization
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 12))

# Plot 1: Distribution of number of bad words per track (Italian)
sns.histplot(tracks['swear_IT'], ax=ax1, bins=20)
ax1.set_title('Distribution of Italian Bad Words per Track')
ax1.set_xlabel('Number of bad words')
ax1.set_ylabel('Number of tracks')

# Plot 2: Distribution of number of bad words per track (English)
sns.histplot(tracks['swear_EN'], ax=ax2, bins=20)
ax2.set_title('Distribution of English Bad Words per Track')
ax2.set_xlabel('Number of bad words')
ax2.set_ylabel('Number of tracks')

# Plot 3: Top 10 most common Italian bad words
if len(it_word_counts) > 0:
    it_word_counts.head(10).plot(kind='bar', ax=ax3)
    ax3.set_title('Top 10 Most Common Italian Bad Words')
    ax3.set_xlabel('Word')
    ax3.set_ylabel('Frequency')
    plt.setp(ax3.xaxis.get_majorticklabels(), rotation=45, ha='right')

# Plot 4: Top 10 most common English bad words
if len(en_word_counts) > 0:
    en_word_counts.head(10).plot(kind='bar', ax=ax4)
    ax4.set_title('Top 10 Most Common English Bad Words')
    ax4.set_xlabel('Word')
    ax4.set_ylabel('Frequency')
    plt.setp(ax4.xaxis.get_majorticklabels(), rotation=45, ha='right')

plt.tight_layout()
plt.show()

# Print summary statistics
print("\nSummary Statistics:")
print(f"Total number of tracks with Italian bad words: {(tracks['swear_IT'] > 0).sum()}")
print(f"Total number of tracks with English bad words: {(tracks['swear_EN'] > 0).sum()}")
print(f"Total unique Italian bad words: {len(it_word_counts)}")
print(f"Total unique English bad words: {len(en_word_counts)}")
print("\nMost common Italian bad words:")
print(it_word_counts.head().to_string())
print("\nMost common English bad words:")
print(en_word_counts.head().to_string())
# Out:
# Summary Statistics:
# Total number of tracks with Italian bad words: 6830
# Total number of tracks with English bad words: 2673
# Total unique Italian bad words: 171
# Total unique English bad words: 94
#
# Most common Italian bad words:
# cazzo      3099
# merda      2026
# culo       1563
# puttana     591
# palle       577
#
# Most common English bad words:
# bitch       763
# fuck        435
# shit        345
# pussy       301
# bastardo    207

# %% [markdown]
# Extract swear word lists, convert counts to numeric, and prepare series of Italian and English swear words for frequency analysis and plotting.

# %%
# Create detailed analysis of bad words occurrences
def print_word_statistics(word_counts, total_tracks, language):
    print(f"\n{'-'*50}")
    print(f"Complete list of {language} bad words:")
    print(f"{'-'*50}")
    print(f"{'Word':<20} {'Occurrences':<15} {'% of Tracks':<15}")
    print(f"{'-'*50}")
    
    for word, count in word_counts.items():
        percentage = (count / total_tracks) * 100
        print(f"{word:<20} {count:<15} {percentage:.2f}%")

# Calculate total number of tracks
total_tracks = len(tracks)

# Print statistics for Italian bad words
print_word_statistics(it_word_counts, total_tracks, "Italian")

# Print statistics for English bad words
print_word_statistics(en_word_counts, total_tracks, "English")

# Additional summary statistics
print(f"\n{'-'*50}")
print("Summary:")
print(f"{'-'*50}")
print(f"Total tracks analyzed: {total_tracks}")
print(f"Total unique Italian bad words: {len(it_word_counts)}")
print(f"Total unique English bad words: {len(en_word_counts)}")
print(f"Total Italian bad word occurrences: {sum(it_word_counts)}")
print(f"Total English bad word occurrences: {sum(en_word_counts)}")
print(f"Average Italian bad words per track: {sum(it_word_counts)/total_tracks:.2f}")
print(f"Average English bad words per track: {sum(en_word_counts)/total_tracks:.2f}")
# Out:
# --------------------------------------------------
# Complete list of Italian bad words:
# --------------------------------------------------
# Word                 Occurrences     % of Tracks
# --------------------------------------------------
# cazzo                3099            28.89%
# merda                2026            18.89%
# culo                 1563            14.57%
# puttana              591             5.51%
# palle                577             5.38%
# troia                558             5.20%
# figa                 556             5.18%
# cazzi                543             5.06%
# stronzo              464             4.33%
# fortuna              344             3.21%
# fottuto              339             3.16%
# cesso                288             2.68%
# coglioni             269             2.51%
# stupido              246             2.29%
# fottere              243             2.27%
# coglione             231             2.15%
# bastardo             207             1.93%
# bastardi             200             1.86%
# piscio               195             1.82%
# figo                 194             1.81%
# vaffanculo           176             1.64%
# madonna              150             1.40%
# gay                  144             1.34%
# scopare              143             1.33%
# sfiga                140             1.30%
# cagare               127             1.18%
# sega                 117             1.09%
# vacca                112             1.04%
# stupida              101             0.94%
# toro                 95              0.89%
# fottuti              93              0.87%
# sedere               91              0.85%
# fica                 90              0.84%
# porca                83              0.77%
# cagna                81              0.76%
# mazzo                77              0.72%
# grilletto            75              0.70%
# selvaggio            66              0.62%
# fesso                63              0.59%
# uccello              59              0.55%
# frocio               57              0.53%
# cazzata              57              0.53%
# pene                 55              0.51%
# incazzato            54              0.50%
# fogna                52              0.48%
# pippa                49              0.46%
# zoccola              43              0.40%
# cretino              43              0.40%
# scopata              42              0.39%
# fico                 40              0.37%
# pisciare             33              0.31%
# scazzo               33              0.31%
# mignotta             32              0.30%
# fogne                31              0.29%
# fregna               29              0.27%
# water                26              0.24%
# stronzata            25              0.23%
# incazzare            25              0.23%
# cazzone              24              0.22%
# cappella             23              0.21%
# cacca                22              0.21%
# cozza                21              0.20%
# travestito           21              0.20%
# leccaculo            18              0.17%
# fregare              18              0.17%
# bocchino             18              0.17%
# pisello              18              0.17%
# cazzeggiare          16              0.15%
# farabutto            16              0.15%
# cazzeggio            15              0.14%
# farabutti            15              0.14%
# cornuto              14              0.13%
# ricchione            14              0.13%
# cretini              14              0.13%
# pipa                 14              0.13%
# tetta                13              0.12%
# chiavare             13              0.12%
# blowjob              13              0.12%
# vagina               13              0.12%
# pompino              13              0.12%
# chiappa              13              0.12%
# gnocca               13              0.12%
# granchio             12              0.11%
# minchioni            12              0.11%
# piccione             12              0.11%
# feci                 12              0.11%
# sboccare             11              0.10%
# sorca                11              0.10%
# zanzara              11              0.10%
# sfigata              11              0.10%
# paraculo             11              0.10%
# spagnola             11              0.10%
# finocchio            11              0.10%
# idiozia              10              0.09%
# sborra               10              0.09%
# sveltina             10              0.09%
# cacare               10              0.09%
# topa                 10              0.09%
# maiala               9               0.08%
# checca               9               0.08%
# inculare             8               0.07%
# handicappato         8               0.07%
# pecorina             8               0.07%
# sgualdrina           8               0.07%
# battona              8               0.07%
# maroni               7               0.07%
# arrapato             7               0.07%
# cagata               7               0.07%
# pisciata             6               0.06%
# fottio               6               0.06%
# scassare             6               0.06%
# chiavata             6               0.06%
# glutei               6               0.06%
# controcazzi          6               0.06%
# pugnetta             5               0.05%
# cazzuto              5               0.05%
# fava                 5               0.05%
# fellatio             5               0.05%
# zizza                5               0.05%
# cretina              5               0.05%
# cacata               4               0.04%
# cogliona             4               0.04%
# bagascia             4               0.04%
# strafottenza         4               0.04%
# sputtanare           4               0.04%
# scrofa               4               0.04%
# schizzare            4               0.04%
# scazzato             4               0.04%
# controcoglioni       4               0.04%
# missionario          4               0.04%
# puttaniere           4               0.04%
# fottersi             4               0.04%
# arrapante            3               0.03%
# scoreggia            3               0.03%
# spompinare           3               0.03%
# fregarsene           3               0.03%
# puttanaio            3               0.03%
# puttanata            3               0.03%
# sborrare             3               0.03%
# mezzasega            3               0.03%
# bombare              3               0.03%
# peluria              3               0.03%
# deretano             3               0.03%
# nerchia              2               0.02%
# escremento           2               0.02%
# pompinara            2               0.02%
# minchiata            2               0.02%
# bernarda             2               0.02%
# segaiolo             2               0.02%
# troiaio              2               0.02%
# arrapare             2               0.02%
# incazzarsi           2               0.02%
# rompicoglioni        2               0.02%
# bocchinaro           2               0.02%
# merdina              2               0.02%
# puttano              1               0.01%
# trombare             1               0.01%
# jug                  1               0.01%
# bischero             1               0.01%
# seccatore            1               0.01%
# culattone            1               0.01%
# smerdare             1               0.01%
# troiaggine           1               0.01%
# cunnu                1               0.01%
# raspa                1               0.01%
# rompipalle           1               0.01%
# vaccata              1               0.01%
# merdata              1               0.01%
# rottinculo           1               0.01%
# coglionata           1               0.01%
# merdaio              1               0.01%
#
# --------------------------------------------------
# Complete list of English bad words:
# --------------------------------------------------
# Word                 Occurrences     % of Tracks
# --------------------------------------------------
# bitch                763             7.11%
# fuck                 435             4.05%
# shit                 345             3.22%
# pussy                301             2.81%
# bastardo             207             1.93%
# bitches              203             1.89%
# hardcore             197             1.84%
# porno                176             1.64%
# sex                  128             1.19%
# negro                108             1.01%
# sexy                 106             0.99%
# ass                  86              0.80%
# nigga                84              0.78%
# escort               80              0.75%
# cock                 71              0.66%
# fucking              57              0.53%
# dick                 56              0.52%
# nude                 56              0.52%
# playboy              45              0.42%
# bullshit             40              0.37%
# fuckin               33              0.31%
# viagra               29              0.27%
# motherfucker         28              0.26%
# milf                 28              0.26%
# bastard              27              0.25%
# dildo                20              0.19%
# suck                 18              0.17%
# threesome            17              0.16%
# lolita               14              0.13%
# faggot               14              0.13%
# vagina               13              0.12%
# porn                 13              0.12%
# blowjob              13              0.12%
# snatch               13              0.12%
# cialis               11              0.10%
# cunt                 11              0.10%
# rape                 10              0.09%
# butt                 8               0.07%
# bondage              8               0.07%
# deepthroat           8               0.07%
# cumshot              7               0.07%
# sexo                 7               0.07%
# xxx                  7               0.07%
# anal                 7               0.07%
# cum                  6               0.06%
# boobs                6               0.06%
# vulva                6               0.06%
# topless              6               0.06%
# hentai               6               0.06%
# fisting              5               0.05%
# titty                5               0.05%
# fellatio             5               0.05%
# clit                 4               0.04%
# xx                   4               0.04%
# gangbang             4               0.04%
# kinky                4               0.04%
# voyeur               4               0.04%
# tits                 4               0.04%
# fag                  4               0.04%
# slut                 3               0.03%
# pissing              3               0.03%
# sexual               3               0.03%
# creampie             3               0.03%
# poof                 3               0.03%
# hooker               2               0.02%
# coon                 2               0.02%
# punany               2               0.02%
# rapist               2               0.02%
# shitty               2               0.02%
# shibari              2               0.02%
# bukkake              2               0.02%
# asshole              2               0.02%
# scat                 2               0.02%
# horny                2               0.02%
# tranny               1               0.01%
# pedobear             1               0.01%
# cumming              1               0.01%
# rimming              1               0.01%
# panties              1               0.01%
# sucks                1               0.01%
# skeet                1               0.01%
# raping               1               0.01%
# anus                 1               0.01%
# domination           1               0.01%
# bbw                  1               0.01%
# spic                 1               0.01%
# busty                1               0.01%
# cocks                1               0.01%
# semen                1               0.01%
# masturbation         1               0.01%
# neonazi              1               0.01%
# doggystyle           1               0.01%
# nympho               1               0.01%
# nipple               1               0.01%
#
# --------------------------------------------------
# Summary:
# --------------------------------------------------
# Total tracks analyzed: 10728
# Total unique Italian bad words: 171
# Total unique English bad words: 94
# Total Italian bad word occurrences: 16375
# Total English bad word occurrences: 4036
# Average Italian bad words per track: 1.53
# Average English bad words per track: 0.38

# %%
# Swear words analysis
# let's first see some upper and lower bounds for popularity
print(f"Max popularity value: {tracks['popularity'].max()}")
print(f"Min popularity value: {tracks['popularity'].min()}")
print(f"Mean popularity: {tracks['popularity'].mean()}")
print(f"Median popularity: {tracks['popularity'].median()}")
print(f"Italian swear words [Max - Mean]: [{tracks['swear_IT'].max()} - {tracks['swear_IT'].mean():.2f}]")
print(f"English swear words [Max - Mean]: [{tracks['swear_EN'].max()} - {tracks['swear_EN'].mean():.2f}]")

# We can see that there are some odd values for popularity to explore, minimum value seems odd, same for max value which is very high, let's plot a distribution of popularity values
# we can observe that around 3x more italian swear words are used compared to english, this was expected as we are analyzing italian rap
# additionally we can see a low usage of swear words
plot_scatter(tracks, 'swear_IT', 'popularity', 'Swear Words', 'Popularity', 'Popularity vs Swear words')

plt.figure(figsize=(12, 6))
plt.scatter(tracks['swear_IT'], tracks['popularity'], label='IT Swear Words')
plt.scatter(tracks['swear_EN'], tracks['popularity'], label='EN Swear Words')
plt.xlabel('Num Swear Words', fontsize=12)
plt.ylabel('Popularity', fontsize=12)
plt.title('Swear Words vs Track Popularity', fontsize=14, fontweight='bold')
plt.legend(fontsize=11)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Max popularity value: 993842
# Min popularity value: -954
# Mean popularity: 830.1945041592672
# Median popularity: 32.0
# Italian swear words [Max - Mean]: [72 - 2.40]
# English swear words [Max - Mean]: [72 - 0.72]

# %% [markdown]
# We cannot see much due to popularity values being out of expected range [0, 100] as specified by the [spotify API](https://developer.spotify.com/documentation/web-api/reference/search). Let's filter tracks with popularity < 100 and > 0.

# %%
lost_songs_count = len(tracks[(tracks['popularity'] > 100) | (tracks['popularity'] < 0)])

# filter
tracks = tracks[(tracks['popularity'] <= 100) & (tracks['popularity'] >= 0)]

print(f"Invalid popularity filter. Lost tracks: {lost_songs_count}")
# Out:
# Invalid popularity filter. Lost tracks: 45

# %%
# Swear words analysis
# let's first see some upper and lower bounds for popularity
print(f"Max popularity value: {tracks['popularity'].max()}")
print(f"Min popularity value: {tracks['popularity'].min()}")
print(f"Mean popularity: {tracks['popularity'].mean()}")
print(f"Median popularity: {tracks['popularity'].median()}")
print(f"Italian swear words [Max - Mean]: [{tracks['swear_IT'].max()} - {tracks['swear_IT'].mean():.2f}]")
print(f"English swear words [Max - Mean]: [{tracks['swear_EN'].max()} - {tracks['swear_EN'].mean():.2f}]")

# We can see that there are some odd values for popularity to explore, minimum value seems odd, same for max value which is very high, let's plot a distribution of popularity values
# we can observe that around 3x more italian swear words are used compared to english, this was expected as we are analyzing italian rap
# additionally we can see a low usage of swear words
plot_scatter(tracks, 'swear_IT', 'popularity', 'Swear Words', 'Popularity', 'Popularity vs Swear words')

plt.figure(figsize=(12, 6))
plt.scatter(tracks['swear_IT'], tracks['popularity'], label='IT Swear Words')
plt.scatter(tracks['swear_EN'], tracks['popularity'], label='EN Swear Words')
plt.xlabel('Num Swear Words', fontsize=12)
plt.ylabel('Popularity', fontsize=12)
plt.title('Swear Words vs Track Popularity', fontsize=14, fontweight='bold')
plt.legend(fontsize=11)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Max popularity value: 100
# Min popularity value: 0
# Mean popularity: 32.74244415243101
# Median popularity: 32.0
# Italian swear words [Max - Mean]: [72 - 2.41]
# English swear words [Max - Mean]: [72 - 0.72]

# %%
plot_boxplot(tracks, ["swear_IT", "swear_EN"], "Boxplot of swear words usage per song")
plot_boxplot(tracks, ["popularity"], "Popularity boxplot")
# Out:
# Quartile Stats
# Column swear_IT:
#   Min value: 0.00
#   Q1 (25%): 0.00
#   Q2 (50%): 1.00
#   Q3 (75%): 3.00
#   Max value: 72.00
#   IQR (Q3-Q1): 3.00
#
#
# Column swear_EN:
#   Min value: 0.00
#   Q1 (25%): 0.00
#   Q2 (50%): 0.00
#   Q3 (75%): 1.00
#   Max value: 72.00
#   IQR (Q3-Q1): 1.00
# Quartile Stats
# Column popularity:
#   Min value: 0.00
#   Q1 (25%): 16.00
#   Q2 (50%): 32.00
#   Q3 (75%): 47.00
#   Max value: 100.00
#   IQR (Q3-Q1): 31.00

# %% [markdown]
# Let's join the tracks and artists dataset to analyze the number of tracks made by each artist

# %%
merged = tracks.merge(artists, left_on='id_artist', right_on='id_author', how='outer')

print(f"Total records after merge: {len(merged)}")
print(f"Original tracks: {len(tracks)}")
print(f"Original artists: {len(artists)}")
print(f"Lost rows: {len(merged)-len(tracks)}")
print(f"Tracks without artist info: {merged['id_author'].isna().sum()}")
print(f"Artists without tracks: {merged['id'].isna().sum()}")

groups = merged.groupby(by='id_artist')
    
plot_nans_stacked(merged, "Missing Data After Merge")

songs_per_author = merged.groupby('id_artist').size()

# summary stats
print(f"Min songs made by an artist: {songs_per_author.min()}")
print(f"Max songs made by an artist: {songs_per_author.max()}")
print(f"Mean songs per artist: {songs_per_author.mean()}")
print(f"Median songs per artist: {songs_per_author.median()}")

# top 10 artists with song count
print("\nTop 10 artists by number of songs:")
top_authors = songs_per_author.sort_values(ascending=False).head(10)

for artist_id, count in top_authors.items():
    artist_name = merged[merged['id_artist'] == artist_id]['name_artist'].iloc[0]
    print(f"{artist_name}: {count}")
# Out:
# Total records after merge: 10655
# Original tracks: 10654
# Original artists: 104
# Lost rows: 1
# Tracks without artist info: 0
# Artists without tracks: 1
#                    NaN Values %  NaN Values  Non-NaN Values %
# active_end           100.000000       10655          0.000000
# featured_artists      67.855467        7230         32.144533
# stats_pageviews       56.546222        6025         43.453778
# age_at_start          45.743782        4874         54.256218
# active_start_year     40.769592        4344         59.230408
# ...                         ...         ...               ...
# track_number           0.009385           1         99.990615
# album_type             0.009385           1         99.990615
# id_author              0.000000           0        100.000000
# gender                 0.000000           0        100.000000
# name                   0.000000           0        100.000000
#
# [65 rows x 3 columns]
# Min songs made by an artist: 2
# Max songs made by an artist: 349
# Mean songs per artist: 103.4368932038835
# Median songs per artist: 91.0
#
# Top 10 artists by number of songs:
# Mondo Marcio: 349
# Gemitaiz: 333
# Guè: 333
# Bassi Maestro: 275
# Fabri Fibra: 273
# Vacca: 268
# Emis Killa: 235
# Achille Lauro: 194
# Salmo: 186
# Lazza: 185

# %% [markdown]
# Print detailed statistics and percentages for Italian and English bad words and display summary metrics.

# %% [markdown]
# # Enrichment of the dataset and fix of data using Spotify API

# %%
tracks_enriched = pd.read_csv("../enriched_datasets/tracks_enriched.csv", sep=',')
artists_enriched = pd.read_csv("../enriched_datasets/artists.csv", sep=',')

# %% [markdown]
# Load enriched datasets generated via API enrichment (`tracks_enriched`, `artists_enriched`) for post-processing and verification.

# %%
artists_enriched.head()
# Out:
#      id_author         name gender  birth_date birth_place nationality  \
# 0  ART82291002     99 posse    NaN         NaN      Napoli    Italiana
# 1  ART18853907         alfa      M  2000-08-19      Genova    Italiana
# 2  ART64265460    anna pepe      F  2003-08-15   La Spezia    Italiana
# 3  ART75741740  articolo 31    NaN         NaN      Milano    Italiana
# 4  ART19605256         beba      F  1994-10-16      Torino    Italiana
#
#                         description active_start  active_end province  \
# 0  Gruppo musicale hip hop italiano   1991-01-01         NaN      NaN
# 1      Cantautore e rapper italiano   2018-01-01         NaN       GE
# 2                   Rapper italiana   2020-01-01         NaN       SP
# 3  Gruppo musicale hip hop italiano   1990-01-01         NaN       MI
# 4                   Rapper italiana   2017-01-01         NaN       TO
#
#       region country  latitude  longitude  \
# 0   Campania  Italia   40.8518    14.2681
# 1    Liguria  Italia   44.4056     8.9463
# 2    Liguria  Italia   44.1024     9.8241
# 3  Lombardia  Italia   45.4642     9.1900
# 4   Piemonte  Italia   45.0703     7.6869
#
#                                   source
# 0         it.wikipedia.org/wiki/99_Posse
# 1  it.wikipedia.org/wiki/Alfa_(cantante)
# 2    it.wikipedia.org/wiki/Anna_(rapper)
# 3      it.wikipedia.org/wiki/Articolo_31
# 4    it.wikipedia.org/wiki/Beba_(rapper)

# %% [markdown]
# Preview the first rows of the enriched `artists` dataset to confirm enrichment results and schema.

# %%
tracks_enriched.head()
# Out:
#          id    id_artist    name_artist  \
# 0  TR934808  ART04205421  Rosa Chemical
# 1  TR760029  ART04205421  Rosa Chemical
# 2  TR916821  ART04205421  Rosa Chemical
# 3  TR480968  ART04205421  Rosa Chemical
# 4  TR585039  ART04205421  Rosa Chemical
#
#                                           full_title         title  \
# 0    ​polka 2 :-/ by Rosa Chemical (Ft. Ernia & Guè)  ​polka 2 :-/
# 1         POLKA by Rosa Chemical (Ft. Thelonious B.)         POLKA
# 2  ​britney ;-) by Rosa Chemical (Ft. MamboLosco ...  ​britney ;-)
# 3                  CEO by Rosa Chemical (Ft. Taxi B)           CEO
# 4                LONDRA by Rosa Chemical (Ft. Rkomi)        LONDRA
#
#       featured_artists primary_artist language              album  \
# 0           Ernia, Guè  Rosa Chemical       pl   FOREVER AND EVER
# 1        Thelonious B.  Rosa Chemical       en   FOREVER AND EVER
# 2  MamboLosco, RADICAL  Rosa Chemical       en   FOREVER AND EVER
# 3               Taxi B  Rosa Chemical       it  OKAY OKAY !! - EP
# 4                Rkomi  Rosa Chemical       en   FOREVER AND EVER
#
#    stats_pageviews  ...  album_type  disc_number track_number duration_ms  \
# 0         196033.0  ...       album          1.0          3.0    207761.0
# 1         164450.0  ...       album          1.0          3.0    207761.0
# 2          58313.0  ...       album          1.0          1.0    193544.0
# 3          39890.0  ...      single          1.0          2.0    169000.0
# 4          35432.0  ...       album          1.0          8.0    194779.0
#
#   explicit  popularity                                        album_image  \
# 0     True        46.0  https://i.scdn.co/image/ab67616d0000b2736d5e14...
# 1     True        46.0  https://i.scdn.co/image/ab67616d0000b2736d5e14...
# 2     True        39.0  https://i.scdn.co/image/ab67616d0000b2736d5e14...
# 3     True        47.0  https://i.scdn.co/image/ab67616d0000b27367c03d...
# 4     True        41.0  https://i.scdn.co/image/ab67616d0000b273fcdb60...
#
#     id_album                                             lyrics  \
# 0  ALB115557  Oplà, ah\nBdope, chiama due b—\n\nMi candidere...
# 1  ALB115557  Greg Willen, non dormire\n(Brr-poh)\n\nT-T-Tro...
# 2  ALB115557  Mothz\nYeah, yeah, yeah-yeah\nBdope, chiama du...
# 3  ALB730959  Designer sui vestiti penso di essere un outlet...
# 4  ALB436151  Bdope (Yeah)\n\nVuole solo me, non fare la gel...
#
#    modified_popularity
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
#
# [5 rows x 45 columns]

# %% [markdown]
# Preview the first rows of the enriched `tracks` dataset to confirm enrichment results and schema.

# %%
artists_enriched.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_author     104 non-null    object
#  1   name          104 non-null    object
#  2   gender        97 non-null     object
#  3   birth_date    88 non-null     object
#  4   birth_place   98 non-null     object
#  5   nationality   103 non-null    object
#  6   description   104 non-null    object
#  7   active_start  65 non-null     object
#  8   active_end    0 non-null      float64
#  9   province      93 non-null     object
#  10  region        93 non-null     object
#  11  country       102 non-null    object
#  12  latitude      98 non-null     float64
#  13  longitude     98 non-null     float64
#  14  source        31 non-null     object
# dtypes: float64(3), object(12)
# memory usage: 12.3+ KB

# %% [markdown]
# Show `artists_enriched.info()` to inspect dtypes and non-null counts after enrichment.

# %%
tracks_enriched.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11166 entries, 0 to 11165
# Data columns (total 45 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    11166 non-null  object
#  1   id_artist             11166 non-null  object
#  2   name_artist           11166 non-null  object
#  3   full_title            11166 non-null  object
#  4   title                 11166 non-null  object
#  5   featured_artists      3517 non-null   object
#  6   primary_artist        11166 non-null  object
#  7   language              11061 non-null  object
#  8   album                 9652 non-null   object
#  9   stats_pageviews       4642 non-null   float64
#  10  swear_IT              11166 non-null  int64
#  11  swear_EN              11166 non-null  int64
#  12  swear_IT_words        11166 non-null  object
#  13  swear_EN_words        11166 non-null  object
#  14  year                  10951 non-null  object
#  15  month                 10366 non-null  float64
#  16  day                   10332 non-null  float64
#  17  n_sentences           11090 non-null  float64
#  18  n_tokens              11090 non-null  float64
#  19  tokens_per_sent       11090 non-null  float64
#  20  char_per_tok          11090 non-null  float64
#  21  lexical_density       11090 non-null  float64
#  22  avg_token_per_clause  11090 non-null  float64
#  23  bpm                   11102 non-null  float64
#  24  centroid              11102 non-null  float64
#  25  rolloff               11102 non-null  float64
#  26  flux                  11102 non-null  float64
#  27  rms                   11102 non-null  float64
#  28  zcr                   11102 non-null  float64
#  29  flatness              11102 non-null  float64
#  30  spectral_complexity   11102 non-null  float64
#  31  pitch                 11102 non-null  float64
#  32  loudness              11102 non-null  float64
#  33  album_name            11088 non-null  object
#  34  album_release_date    11088 non-null  object
#  35  album_type            11088 non-null  object
#  36  disc_number           11088 non-null  float64
#  37  track_number          11088 non-null  float64
#  38  duration_ms           11088 non-null  float64
#  39  explicit              11088 non-null  object
#  40  popularity            11166 non-null  float64
#  41  album_image           11088 non-null  object
#  42  id_album              11088 non-null  object
#  43  lyrics                11163 non-null  object
#  44  modified_popularity   11166 non-null  bool
# dtypes: bool(1), float64(23), int64(2), object(19)
# memory usage: 3.8+ MB

# %% [markdown]
# From the data types analysis we have to cast back the values like we did for the original dataset, let's do it

# %%
columns_to_string   = ["id", "id_artist", "name_artist", "full_title", "title", "featured_artists", "primary_artist", "language", "album", "album_name", "album_type", "lyrics", "album_image", "id_album"]
for column in columns_to_string:
    tracks_enriched[column] = tracks_enriched[column].astype('string')
    
# these columns are array of strings, let's leave them as objects
columns_to_array = ["swear_IT_words", "swear_EN_words"]

# to datetime
tracks_enriched['album_release_date'] = pd.to_datetime(tracks_enriched['album_release_date'], errors='coerce')
tracks_enriched['popularity'] = tracks_enriched['popularity'].apply(pd.to_numeric, errors='coerce')
tracks_enriched['popularity'] = tracks_enriched['popularity'].astype('Int64')

# from df.info we can see that this column is a boolean, so let's cast it to bool
tracks_enriched['explicit'] = tracks_enriched['explicit'].astype('bool')

# different values, like NaN or 2021.0 so cast to int
tracks_enriched['year'] = tracks_enriched['year'].apply(pd.to_numeric, errors='coerce')
tracks_enriched["year"] = tracks_enriched['year'].astype('Int64') 

tracks_enriched.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11166 entries, 0 to 11165
# Data columns (total 45 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    11166 non-null  string
#  1   id_artist             11166 non-null  string
#  2   name_artist           11166 non-null  string
#  3   full_title            11166 non-null  string
#  4   title                 11166 non-null  string
#  5   featured_artists      3517 non-null   string
#  6   primary_artist        11166 non-null  string
#  7   language              11061 non-null  string
#  8   album                 9652 non-null   string
#  9   stats_pageviews       4642 non-null   float64
#  10  swear_IT              11166 non-null  int64
#  11  swear_EN              11166 non-null  int64
#  12  swear_IT_words        11166 non-null  object
#  13  swear_EN_words        11166 non-null  object
#  14  year                  10929 non-null  Int64
#  15  month                 10366 non-null  float64
#  16  day                   10332 non-null  float64
#  17  n_sentences           11090 non-null  float64
#  18  n_tokens              11090 non-null  float64
#  19  tokens_per_sent       11090 non-null  float64
#  20  char_per_tok          11090 non-null  float64
#  21  lexical_density       11090 non-null  float64
#  22  avg_token_per_clause  11090 non-null  float64
#  23  bpm                   11102 non-null  float64
#  24  centroid              11102 non-null  float64
#  25  rolloff               11102 non-null  float64
#  26  flux                  11102 non-null  float64
#  27  rms                   11102 non-null  float64
#  28  zcr                   11102 non-null  float64
#  29  flatness              11102 non-null  float64
#  30  spectral_complexity   11102 non-null  float64
#  31  pitch                 11102 non-null  float64
#  32  loudness              11102 non-null  float64
#  33  album_name            11088 non-null  string
#  34  album_release_date    10827 non-null  datetime64[ns]
#  35  album_type            11088 non-null  string
#  36  disc_number           11088 non-null  float64
#  37  track_number          11088 non-null  float64
#  38  duration_ms           11088 non-null  float64
#  39  explicit              11166 non-null  bool
#  40  popularity            11166 non-null  Int64
#  41  album_image           11088 non-null  string
#  42  id_album              11088 non-null  string
#  43  lyrics                11163 non-null  string
#  44  modified_popularity   11166 non-null  bool
# dtypes: Int64(2), bool(2), datetime64[ns](1), float64(22), int64(2), object(2), string(14)
# memory usage: 3.7+ MB

# %%
columns_to_string   = ["id_author", "name", "gender", "birth_place", "nationality", "description", "province", "region", "country"]
for column in columns_to_string:
    artists_enriched[column] = artists_enriched[column].astype('string')
    
columns_to_datetime = ["birth_date", "active_start", "active_end"]
for column in columns_to_datetime:
    artists_enriched[column] = pd.to_datetime(artists_enriched[column], errors='coerce')

artists_enriched.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_author          104 non-null    string
#  1   name               104 non-null    string
#  2   gender             104 non-null    string
#  3   birth_date         72 non-null     datetime64[ns]
#  4   birth_place        72 non-null     string
#  5   nationality        71 non-null     string
#  6   description        86 non-null     string
#  7   active_start       50 non-null     datetime64[ns]
#  8   active_end         0 non-null      datetime64[ns]
#  9   province           70 non-null     string
#  10  region             68 non-null     string
#  11  country            70 non-null     string
#  12  latitude           72 non-null     float64
#  13  longitude          72 non-null     float64
#  14  birth_year         72 non-null     float64
#  15  active_start_year  50 non-null     float64
#  16  age_at_start       44 non-null     float64
# dtypes: datetime64[ns](3), float64(5), string(9)
# memory usage: 13.9 KB

# %% [markdown]
# From the `.info()` function in pandas we can see that all data types have been effectively casted.

# %%
## Artists after enrichment
# Check how many NaNs are present and plot the number of NaN per each column
# from the distribution we can see that no active end date is present, and about half active start
plot_nans_stacked(artists_enriched, 'NaN Percentage Per Column (Artists Dataset enriched)')
# Out:
#               NaN Values %  NaN Values  Non-NaN Values %
# active_end      100.000000         104          0.000000
# source           70.192308          73         29.807692
# active_start     37.500000          39         62.500000
# birth_date       15.384615          16         84.615385
# province         10.576923          11         89.423077
# region           10.576923          11         89.423077
# gender            6.730769           7         93.269231
# birth_place       5.769231           6         94.230769
# latitude          5.769231           6         94.230769
# longitude         5.769231           6         94.230769
# country           1.923077           2         98.076923
# nationality       0.961538           1         99.038462
# description       0.000000           0        100.000000
# id_author         0.000000           0        100.000000
# name              0.000000           0        100.000000

# %%
## Tracks after enrichment
# Check how many NaNs are present and plot the number of NaN per each column
plot_nans_stacked(tracks_enriched, 'NaN Percentage Per Column (Tracks Dataset enriched)')
# Out:
#                       NaN Values %  NaN Values  Non-NaN Values %
# featured_artists         68.502597        7649         31.497403
# stats_pageviews          58.427369        6524         41.572631
# album                    13.559018        1514         86.440982
# day                       7.469103         834         92.530897
# month                     7.164607         800         92.835393
# album_release_date        3.036002         339         96.963998
# year                      2.122515         237         97.877485
# language                  0.940355         105         99.059645
# album_type                0.698549          78         99.301451
# album_image               0.698549          78         99.301451
# disc_number               0.698549          78         99.301451
# album_name                0.698549          78         99.301451
# track_number              0.698549          78         99.301451
# id_album                  0.698549          78         99.301451
# duration_ms               0.698549          78         99.301451
# avg_token_per_clause      0.680638          76         99.319362
# n_sentences               0.680638          76         99.319362
# tokens_per_sent           0.680638          76         99.319362
# n_tokens                  0.680638          76         99.319362
# char_per_tok              0.680638          76         99.319362
# lexical_density           0.680638          76         99.319362
# pitch                     0.573169          64         99.426831
# flatness                  0.573169          64         99.426831
# flux                      0.573169          64         99.426831
# zcr                       0.573169          64         99.426831
# centroid                  0.573169          64         99.426831
# bpm                       0.573169          64         99.426831
# rolloff                   0.573169          64         99.426831
# rms                       0.573169          64         99.426831
# loudness                  0.573169          64         99.426831
# spectral_complexity       0.573169          64         99.426831
# lyrics                    0.026867           3         99.973133
# swear_IT_words            0.000000           0        100.000000
# id_artist                 0.000000           0        100.000000
# name_artist               0.000000           0        100.000000
# full_title                0.000000           0        100.000000
# title                     0.000000           0        100.000000
# id                        0.000000           0        100.000000
# swear_EN                  0.000000           0        100.000000
# swear_IT                  0.000000           0        100.000000
# primary_artist            0.000000           0        100.000000
# swear_EN_words            0.000000           0        100.000000
# explicit                  0.000000           0        100.000000
# popularity                0.000000           0        100.000000
# modified_popularity       0.000000           0        100.000000

# %%
# birth year distribution after enrichment
artists_enriched['birth_year'] = pd.to_datetime(artists_enriched['birth_date'], errors='coerce').dt.year
plot_histogram(artists_enriched, 'birth_year', 'Birth Year', 'Number of Authors', 'Distribution of Authors by Birth Year', nbins=50)

# %%
# Year tracks distribution after enrichment
tracks_enriched['year'] = pd.to_numeric(tracks_enriched['year'], errors='coerce')

# Drop rows where year couldn't be parsed
tracks_enriched = tracks_enriched.dropna(subset=['year'])

# Convert to integer year now that NaNs are removed
tracks_enriched['year'] = tracks_enriched['year'].astype(int)

# Compute decade and plot
tracks_enriched['decade'] = (tracks_enriched['year'] // 10) * 10
plot_histogram(tracks_enriched, 'decade', 'Decade', 'Number of Tracks',
               'Distribution of Tracks by Decade', nbins=10)

plt.show()

# %%
# Month tracks distribution after enrichment
if 'month' in tracks_enriched.columns:
    plt.figure(figsize=(8, 5))
    sns.countplot(
        x=tracks_enriched['month'].dropna().astype(int),
        order=sorted(tracks_enriched['month'].dropna().astype(int).unique())
    )
    plt.title('Distribution of Track Releases by Month')
    plt.xlabel('Month')
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# Let's analyze swear words and popularity values, particularly:
# - Popularity values range pre and after enrichment
# - Swear words analysis

# %%
print(f"Max popularity value: {tracks['popularity'].max()}")
print(f"Min popularity value: {tracks['popularity'].min()}")
print(f"Mean popularity: {tracks['popularity'].mean()}")
print(f"Median popularity: {tracks['popularity'].median()}")
print(f"Italian swear words [Max - Mean]: [{tracks['swear_IT'].max()} - {tracks['swear_IT'].mean():.2f}]")
print(f"English swear words [Max - Mean]: [{tracks['swear_EN'].max()} - {tracks['swear_EN'].mean():.2f}]")
# Out:
# Max popularity value: 100
# Min popularity value: 0
# Mean popularity: 32.74244415243101
# Median popularity: 32.0
# Italian swear words [Max - Mean]: [72 - 2.41]
# English swear words [Max - Mean]: [72 - 0.72]
